# %%
# !kaggle datasets download -d debayan20000/brainsegmentation2018-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/debayan20000/brainsegmentation2018-dataset
# License(s): apache-2.0
# Downloading brainsegmentation2018-dataset.zip to /kaggle/working
#  99%|██████████████████████████████████████▌| 1.93G/1.95G [00:08<00:00, 239MB/s]
# 100%|███████████████████████████████████████| 1.95G/1.95G [00:08<00:00, 244MB/s]

# %%
# !pip install rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.10/site-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from rasterio) (2024.8.30)
# Requirement already satisfied: click>=4.0 in /opt/conda/lib/python3.10/site-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.10/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /opt/conda/lib/python3.10/site-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in /opt/conda/lib/python3.10/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.10/site-packages (from rasterio) (3.1.2)
# Downloading rasterio-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 55.9 MB/s eta 0:00:00
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.4.1

# %%
import zipfile
import os

# Path to your .zip file
zip_file_path = '/kaggle/working/brainsegmentation2018-dataset.zip'

# Directory where you want to extract the files
extract_to_path = '/kaggle/working/'

# Create the extraction directory if it doesn't exist
os.makedirs(extract_to_path, exist_ok=True)

# Unzipping the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to_path)

print("File unzipped successfully!")
# Out:
# File unzipped successfully!

# %%
import os
import numpy as np
import nibabel as nib
import torch
from torch.amp import autocast, GradScaler
from skimage.transform import resize
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import Resize
from sklearn.model_selection import train_test_split
from torch.optim.lr_scheduler import ReduceLROnPlateau
import numpy as np

# %%
class BrainSegmentationDataset(Dataset):
    def __init__(self, root_dir, patch_size=(48, 240, 240), stride=8, transform=None):
        self.root_dir = root_dir
        self.patch_size = (64, 64, 16)
        self.stride = 16
        self.transform = transform
        self.patches_img = []
        self.patches_mask = []

        # Load data and extract patches
        self._load_data()
        print(f"Number of image patches: {len(self.patches_img)}") # Print the number of image patches

    def _load_data(self):
        for subfolder in os.listdir(self.root_dir):
            subfolder_path = os.path.join(self.root_dir, subfolder)
            if os.path.isdir(subfolder_path):
                pre_dir = os.path.join(subfolder_path, 'pre')
                seg_dir = os.path.join(subfolder_path, 'segm.nii')

                # Load MRI modalities
                t1_path = os.path.join(pre_dir, 'T1.nii/T1.nii')
                ir_path = os.path.join(pre_dir, 'IR.nii/IR.nii')
                flair_path = os.path.join(pre_dir, 'FLAIR.nii/FLAIR.nii')
                seg_path = os.path.join(seg_dir, 'segm.nii')

                print(f"Checking for files in subfolder: {subfolder_path}") # Print the subfolder being checked
                print(f" - T1 path: {t1_path}")
                print(f" - IR path: {ir_path}")
                print(f" - FLAIR path: {flair_path}")
                print(f" - Segmentation path: {seg_path}")

                # Check if files exist
                if not os.path.exists(t1_path):
                    print(f" - T1 file not found: {t1_path}")
                if not os.path.exists(ir_path):
                    print(f" - IR file not found: {ir_path}")
                if not os.path.exists(flair_path):
                    print(f" - FLAIR file not found: {flair_path}")
                if not os.path.exists(seg_path):
                    print(f" - Segmentation file not found: {seg_path}")
                    continue  # Skip to the next subfolder

                # Read NIfTI files
                try:
                    t1_img = nib.load(t1_path).get_fdata()
                    ir_img = nib.load(ir_path).get_fdata()
                    flair_img = nib.load(flair_path).get_fdata()
                    seg_img = nib.load(seg_path).get_fdata()

                    # Print shapes after loading images
                    print(f" - T1 shape after loading: {t1_img.shape}")
                    print(f" - IR shape after loading: {ir_img.shape}")
                    print(f" - FLAIR shape after loading: {flair_img.shape}")
                    print(f" - Segmentation shape after loading: {seg_img.shape}")

                except Exception as e:
                    print(f"Error loading images from subfolder {subfolder_path}: {e}")
                    continue

                # Resize the images to the target shape
                t1_img = self._resize(t1_img)
                ir_img = self._resize(ir_img)
                flair_img = self._resize(flair_img)
                seg_img = self._resize(seg_img)

                print(f" - T1 shape: {t1_img.shape}")
                print(f" - IR shape: {ir_img.shape}")
                print(f" - FLAIR shape: {flair_img.shape}")
                print(f" - Segmentation shape: {seg_img.shape}")



                # Extract patches
                img = np.stack([t1_img, ir_img, flair_img], axis=0)  # Shape: (3, D, H, W)
                patches_img, patches_mask = self._extract_patches(img, seg_img)

                # Print number of patches extracted
                print(f" - Number of image patches extracted: {len(patches_img)}")
                print(f" - Number of mask patches extracted: {len(patches_mask)}")


                # Store patches
                self.patches_img.extend(patches_img)
                self.patches_mask.extend(patches_mask)

    def _resize(self, image):
        # Resize image to target shape
        target_shape = (240, 240, 48)  # For simplicity, you can resize to this shape
        return resize(image, target_shape, mode='reflect', anti_aliasing=True)
    def _extract_patches(self, image, mask):
        patches_img = []
        patches_mask = []
        _, depth, height, width = image.shape
        p_depth, p_height, p_width = self.patch_size

        # Check if patch extraction is feasible
        if depth < p_depth or height < p_height or width < p_width:
            print(f"Patch size {self.patch_size} is too large for image dimensions {image.shape}.")
            return patches_img, patches_mask

        print(f"Stride: {self.stride}, Patch size: {self.patch_size}")
        print(f"Depth: {depth}, Height: {height}, Width: {width}")

        # Extract patches
        for i in range(0, depth - p_depth + 1, self.stride):
            for j in range(0, height - p_height + 1, self.stride):
                for k in range(0, width - p_width + 1, self.stride):
                    img_patch = image[:, i:i+p_depth, j:j+p_height, k:k+p_width]
                    mask_patch = mask[i:i+p_depth, j:j+p_height, k:k+p_width]
                    patches_img.append(img_patch)
                    patches_mask.append(mask_patch)
                    print(f"Patch extracted: depth {i}, height {j}, width {k}")

        print(f"Total patches extracted: {len(patches_img)}")
        return np.array(patches_img), np.array(patches_mask)

    def __len__(self):
        return len(self.patches_img)
        print(f"Number of image patches: {len(self.patches_img)}") # Print the number of image patches

    def __getitem__(self, idx):
        img = self.patches_img[idx]
        mask = self.patches_mask[idx]

        if self.transform:
            img = self.transform(img)

        return img, mask

# %%
torch.cuda.empty_cache()

# %%
print(torch.cuda.memory_summary())
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |      0 B   |      0 B   |      0 B   |      0 B   |
# |       from large pool |      0 B   |      0 B   |      0 B   |      0 B   |
# |       from small pool |      0 B   |      0 B   |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | Active memory         |      0 B   |      0 B   |      0 B   |      0 B   |
# |       from large pool |      0 B   |      0 B   |      0 B   |      0 B   |
# |       from small pool |      0 B   |      0 B   |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | Requested memory      |      0 B   |      0 B   |      0 B   |      0 B   |
# |       from large pool |      0 B   |      0 B   |      0 B   |      0 B   |
# |       from small pool |      0 B   |      0 B   |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |      0 B   |      0 B   |      0 B   |      0 B   |
# |       from large pool |      0 B   |      0 B   |      0 B   |      0 B   |
# |       from small pool |      0 B   |      0 B   |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |      0 B   |      0 B   |      0 B   |      0 B   |
# |       from large pool |      0 B   |      0 B   |      0 B   |      0 B   |
# |       from small pool |      0 B   |      0 B   |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | Allocations           |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Active allocs         |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
# Define the dataset paths
train_data_dir = '/kaggle/working/training_dataset'

# %%
dataset = BrainSegmentationDataset(train_data_dir)
# Out:
# Checking for files in subfolder: /kaggle/working/training_dataset/7
#  - T1 path: /kaggle/working/training_dataset/7/pre/T1.nii/T1.nii
#  - IR path: /kaggle/working/training_dataset/7/pre/IR.nii/IR.nii
#  - FLAIR path: /kaggle/working/training_dataset/7/pre/FLAIR.nii/FLAIR.nii
#  - Segmentation path: /kaggle/working/training_dataset/7/segm.nii/segm.nii
#  - T1 shape after loading: (256, 256, 192)
#  - IR shape after loading: (240, 240, 48)
#  - FLAIR shape after loading: (240, 240, 48)
#  - Segmentation shape after loading: (240, 240, 48)
#  - T1 shape: (240, 240, 48)
#  - IR shape: (240, 240, 48)
#  - FLAIR shape: (240, 240, 48)
#  - Segmentation shape: (240, 240, 48)
# Stride: 16, Patch size: (64, 64, 16)
# Depth: 240, Height: 240, Width: 48
# Patch extracted: depth 0, height 0, width 0
# Patch extracted: depth 0, height 0, width 16
# Patch extracted: depth 0, height 0, width 32
# Patch extracted: depth 0, height 16, width 0
# Patch extracted: depth 0, height 16, width 16
# Patch extracted: depth 0, height 16, width 32
# Patch extracted: depth 0, height 32, width 0
# Patch extracted: depth 0, height 32, width 16
# Patch extracted: depth 0, height 32, width 32
# Patch extracted: depth 0, height 48, width 0
# Patch extracted: depth 0, height 48, width 16
# Patch extracted: depth 0, height 48, width 32
# Patch extracted: depth 0, height 64, width 0
# Patch extracted: depth 0, height 64, width 16
# Patch extracted: depth 0, height 64, width 32
# Patch extracted: depth 0, height 80, width 0
# Patch extracted: depth 0, height 80, width 16
# Patch extracted: depth 0, height 80, width 32
# Patch extracted: depth 0, height 96, width 0
# Patch extracted: depth 0, height 96, width 16
# Patch extracted: depth 0, height 96, width 32
# Patch extracted: depth 0, height 112, width 0
# Patch extracted: depth 0, height 112, width 16
# Patch extracted: depth 0, height 112, width 32
# Patch extracted: depth 0, height 128, width 0
# Patch extracted: depth 0, height 128, width 16
# Patch extracted: depth 0, height 128, width 32
# Patch extracted: depth 0, height 144, width 0
# Patch extracted: depth 0, height 144, width 16
# Patch extracted: depth 0, height 144, width 32
# Patch extracted: depth 0, height 160, width 0
# Patch extracted: depth 0, height 160, width 16
# Patch extracted: depth 0, height 160, width 32
# Patch extracted: depth 0, height 176, width 0
# Patch extracted: depth 0, height 176, width 16
# Patch extracted: depth 0, height 176, width 32
# Patch extracted: depth 16, height 0, width 0
# Patch extracted: depth 16, height 0, width 16
# Patch extracted: depth 16, height 0, width 32
# Patch extracted: depth 16, height 16, width 0
# Patch extracted: depth 16, height 16, width 16
# Patch extracted: depth 16, height 16, width 32
# Patch extracted: depth 16, height 32, width 0
# Patch extracted: depth 16, height 32, width 16
# Patch extracted: depth 16, height 32, width 32
# Patch extracted: depth 16, height 48, width 0
# Patch extracted: depth 16, height 48, width 16
# Patch extracted: depth 16, height 48, width 32
# Patch extracted: depth 16, height 64, width 0
# Patch extracted: depth 16, height 64, width 16
# Patch extracted: depth 16, height 64, width 32
# Patch extracted: depth 16, height 80, width 0
# Patch extracted: depth 16, height 80, width 16
# Patch extracted: depth 16, height 80, width 32
# Patch extracted: depth 16, height 96, width 0
# Patch extracted: depth 16, height 96, width 16
# Patch extracted: depth 16, height 96, width 32
# Patch extracted: depth 16, height 112, width 0
# Patch extracted: depth 16, height 112, width 16
# Patch extracted: depth 16, height 112, width 32
# Patch extracted: depth 16, height 128, width 0
# Patch extracted: depth 16, height 128, width 16
# Patch extracted: depth 16, height 128, width 32
# Patch extracted: depth 16, height 144, width 0
# Patch extracted: depth 16, height 144, width 16
# Patch extracted: depth 16, height 144, width 32
# Patch extracted: depth 16, height 160, width 0
# Patch extracted: depth 16, height 160, width 16
# Patch extracted: depth 16, height 160, width 32
# Patch extracted: depth 16, height 176, width 0
# Patch extracted: depth 16, height 176, width 16
# Patch extracted: depth 16, height 176, width 32
# Patch extracted: depth 32, height 0, width 0
# Patch extracted: depth 32, height 0, width 16
# Patch extracted: depth 32, height 0, width 32
# Patch extracted: depth 32, height 16, width 0
# Patch extracted: depth 32, height 16, width 16
# Patch extracted: depth 32, height 16, width 32
# Patch extracted: depth 32, height 32, width 0
# Patch extracted: depth 32, height 32, width 16
# Patch extracted: depth 32, height 32, width 32
# Patch extracted: depth 32, height 48, width 0
# Patch extracted: depth 32, height 48, width 16
# Patch extracted: depth 32, height 48, width 32
# Patch extracted: depth 32, height 64, width 0
# Patch extracted: depth 32, height 64, width 16
# Patch extracted: depth 32, height 64, width 32
# Patch extracted: depth 32, height 80, width 0
# Patch extracted: depth 32, height 80, width 16
# Patch extracted: depth 32, height 80, width 32
# Patch extracted: depth 32, height 96, width 0
# Patch extracted: depth 32, height 96, width 16
# Patch extracted: depth 32, height 96, width 32
# Patch extracted: depth 32, height 112, width 0
# Patch extracted: depth 32, height 112, width 16
# Patch extracted: depth 32, height 112, width 32
# Patch extracted: depth 32, height 128, width 0
# Patch extracted: depth 32, height 128, width 16
# Patch extracted: depth 32, height 128, width 32
# Patch extracted: depth 32, height 144, width 0
# Patch extracted: depth 32, height 144, width 16
# Patch extracted: depth 32, height 144, width 32
# Patch extracted: depth 32, height 160, width 0
# Patch extracted: depth 32, height 160, width 16
# Patch extracted: depth 32, height 160, width 32
# Patch extracted: depth 32, height 176, width 0
# Patch extracted: depth 32, height 176, width 16
# Patch extracted: depth 32, height 176, width 32
# Patch extracted: depth 48, height 0, width 0
# Patch extracted: depth 48, height 0, width 16
# Patch extracted: depth 48, height 0, width 32
# Patch extracted: depth 48, height 16, width 0
# Patch extracted: depth 48, height 16, width 16
# Patch extracted: depth 48, height 16, width 32
# Patch extracted: depth 48, height 32, width 0
# Patch extracted: depth 48, height 32, width 16
# Patch extracted: depth 48, height 32, width 32
# Patch extracted: depth 48, height 48, width 0
# Patch extracted: depth 48, height 48, width 16
# Patch extracted: depth 48, height 48, width 32
# Patch extracted: depth 48, height 64, width 0
# Patch extracted: depth 48, height 64, width 16
# Patch extracted: depth 48, height 64, width 32
# Patch extracted: depth 48, height 80, width 0
# Patch extracted: depth 48, height 80, width 16
# Patch extracted: depth 48, height 80, width 32
# Patch extracted: depth 48, height 96, width 0
# Patch extracted: depth 48, height 96, width 16
# Patch extracted: depth 48, height 96, width 32
# Patch extracted: depth 48, height 112, width 0
# Patch extracted: depth 48, height 112, width 16
# Patch extracted: depth 48, height 112, width 32
# Patch extracted: depth 48, height 128, width 0
# Patch extracted: depth 48, height 128, width 16
# Patch extracted: depth 48, height 128, width 32
# Patch extracted: depth 48, height 144, width 0
# Patch extracted: depth 48, height 144, width 16
# Patch extracted: depth 48, height 144, width 32
# Patch extracted: depth 48, height 160, width 0
# Patch extracted: depth 48, height 160, width 16
# Patch extracted: depth 48, height 160, width 32
# Patch extracted: depth 48, height 176, width 0
# Patch extracted: depth 48, height 176, width 16
# Patch extracted: depth 48, height 176, width 32
# Patch extracted: depth 64, height 0, width 0
# Patch extracted: depth 64, height 0, width 16
# Patch extracted: depth 64, height 0, width 32
# Patch extracted: depth 64, height 16, width 0
# Patch extracted: depth 64, height 16, width 16
# Patch extracted: depth 64, height 16, width 32
# Patch extracted: depth 64, height 32, width 0
# Patch extracted: depth 64, height 32, width 16
# Patch extracted: depth 64, height 32, width 32
# Patch extracted: depth 64, height 48, width 0
# Patch extracted: depth 64, height 48, width 16
# Patch extracted: depth 64, height 48, width 32
# Patch extracted: depth 64, height 64, width 0
# Patch extracted: depth 64, height 64, width 16
# Patch extracted: depth 64, height 64, width 32
# Patch extracted: depth 64, height 80, width 0
# Patch extracted: depth 64, height 80, width 16
# Patch extracted: depth 64, height 80, width 32
# Patch extracted: depth 64, height 96, width 0
# Patch extracted: depth 64, height 96, width 16
# Patch extracted: depth 64, height 96, width 32
# Patch extracted: depth 64, height 112, width 0
# Patch extracted: depth 64, height 112, width 16
# Patch extracted: depth 64, height 112, width 32
# Patch extracted: depth 64, height 128, width 0
# Patch extracted: depth 64, height 128, width 16
# Patch extracted: depth 64, height 128, width 32
# Patch extracted: depth 64, height 144, width 0
# Patch extracted: depth 64, height 144, width 16
# Patch extracted: depth 64, height 144, width 32
# Patch extracted: depth 64, height 160, width 0
# Patch extracted: depth 64, height 160, width 16
# Patch extracted: depth 64, height 160, width 32
# Patch extracted: depth 64, height 176, width 0
# Patch extracted: depth 64, height 176, width 16
# Patch extracted: depth 64, height 176, width 32
# Patch extracted: depth 80, height 0, width 0
# Patch extracted: depth 80, height 0, width 16
# Patch extracted: depth 80, height 0, width 32
# Patch extracted: depth 80, height 16, width 0
# Patch extracted: depth 80, height 16, width 16
# Patch extracted: depth 80, height 16, width 32
# Patch extracted: depth 80, height 32, width 0
# Patch extracted: depth 80, height 32, width 16
# Patch extracted: depth 80, height 32, width 32
# Patch extracted: depth 80, height 48, width 0
# Patch extracted: depth 80, height 48, width 16
# Patch extracted: depth 80, height 48, width 32
# Patch extracted: depth 80, height 64, width 0
# Patch extracted: depth 80, height 64, width 16
# Patch extracted: depth 80, height 64, width 32
# Patch extracted: depth 80, height 80, width 0
# Patch extracted: depth 80, height 80, width 16
# Patch extracted: depth 80, height 80, width 32
# Patch extracted: depth 80, height 96, width 0
# Patch extracted: depth 80, height 96, width 16
# Patch extracted: depth 80, height 96, width 32
# Patch extracted: depth 80, height 112, width 0
# Patch extracted: depth 80, height 112, width 16
# Patch extracted: depth 80, height 112, width 32
# Patch extracted: depth 80, height 128, width 0
# Patch extracted: depth 80, height 128, width 16
# Patch extracted: depth 80, height 128, width 32
# Patch extracted: depth 80, height 144, width 0
# Patch extracted: depth 80, height 144, width 16
# Patch extracted: depth 80, height 144, width 32
# Patch extracted: depth 80, height 160, width 0
# Patch extracted: depth 80, height 160, width 16
# Patch extracted: depth 80, height 160, width 32
# Patch extracted: depth 80, height 176, width 0
# Patch extracted: depth 80, height 176, width 16
# Patch extracted: depth 80, height 176, width 32
# Patch extracted: depth 96, height 0, width 0
# Patch extracted: depth 96, height 0, width 16
# Patch extracted: depth 96, height 0, width 32
# Patch extracted: depth 96, height 16, width 0
# Patch extracted: depth 96, height 16, width 16
# Patch extracted: depth 96, height 16, width 32
# Patch extracted: depth 96, height 32, width 0
# Patch extracted: depth 96, height 32, width 16
# Patch extracted: depth 96, height 32, width 32
# Patch extracted: depth 96, height 48, width 0
# Patch extracted: depth 96, height 48, width 16
# Patch extracted: depth 96, height 48, width 32
# Patch extracted: depth 96, height 64, width 0
# Patch extracted: depth 96, height 64, width 16
# Patch extracted: depth 96, height 64, width 32
# Patch extracted: depth 96, height 80, width 0
# Patch extracted: depth 96, height 80, width 16
# Patch extracted: depth 96, height 80, width 32
# Patch extracted: depth 96, height 96, width 0
# Patch extracted: depth 96, height 96, width 16
# Patch extracted: depth 96, height 96, width 32
# Patch extracted: depth 96, height 112, width 0
# Patch extracted: depth 96, height 112, width 16
# Patch extracted: depth 96, height 112, width 32
# Patch extracted: depth 96, height 128, width 0
# Patch extracted: depth 96, height 128, width 16
# Patch extracted: depth 96, height 128, width 32
# Patch extracted: depth 96, height 144, width 0
# Patch extracted: depth 96, height 144, width 16
# Patch extracted: depth 96, height 144, width 32
# Patch extracted: depth 96, height 160, width 0
# Patch extracted: depth 96, height 160, width 16
# Patch extracted: depth 96, height 160, width 32
# Patch extracted: depth 96, height 176, width 0
# Patch extracted: depth 96, height 176, width 16
# Patch extracted: depth 96, height 176, width 32
# Patch extracted: depth 112, height 0, width 0
# Patch extracted: depth 112, height 0, width 16
# Patch extracted: depth 112, height 0, width 32
# Patch extracted: depth 112, height 16, width 0
# Patch extracted: depth 112, height 16, width 16
# Patch extracted: depth 112, height 16, width 32
# Patch extracted: depth 112, height 32, width 0
# Patch extracted: depth 112, height 32, width 16
# Patch extracted: depth 112, height 32, width 32
# Patch extracted: depth 112, height 48, width 0
# Patch extracted: depth 112, height 48, width 16
# Patch extracted: depth 112, height 48, width 32
# Patch extracted: depth 112, height 64, width 0
# Patch extracted: depth 112, height 64, width 16
# Patch extracted: depth 112, height 64, width 32
# Patch extracted: depth 112, height 80, width 0
# Patch extracted: depth 112, height 80, width 16
# Patch extracted: depth 112, height 80, width 32
# Patch extracted: depth 112, height 96, width 0
# Patch extracted: depth 112, height 96, width 16
# Patch extracted: depth 112, height 96, width 32
# Patch extracted: depth 112, height 112, width 0
# Patch extracted: depth 112, height 112, width 16
# Patch extracted: depth 112, height 112, width 32
# Patch extracted: depth 112, height 128, width 0
# Patch extracted: depth 112, height 128, width 16
# Patch extracted: depth 112, height 128, width 32
# Patch extracted: depth 112, height 144, width 0
# Patch extracted: depth 112, height 144, width 16
# Patch extracted: depth 112, height 144, width 32
# Patch extracted: depth 112, height 160, width 0
# Patch extracted: depth 112, height 160, width 16
# Patch extracted: depth 112, height 160, width 32
# Patch extracted: depth 112, height 176, width 0
# Patch extracted: depth 112, height 176, width 16
# Patch extracted: depth 112, height 176, width 32
# Patch extracted: depth 128, height 0, width 0
# Patch extracted: depth 128, height 0, width 16
# Patch extracted: depth 128, height 0, width 32
# Patch extracted: depth 128, height 16, width 0
# Patch extracted: depth 128, height 16, width 16
# Patch extracted: depth 128, height 16, width 32
# Patch extracted: depth 128, height 32, width 0
# Patch extracted: depth 128, height 32, width 16
# Patch extracted: depth 128, height 32, width 32
# Patch extracted: depth 128, height 48, width 0
# Patch extracted: depth 128, height 48, width 16
# Patch extracted: depth 128, height 48, width 32
# Patch extracted: depth 128, height 64, width 0
# Patch extracted: depth 128, height 64, width 16
# Patch extracted: depth 128, height 64, width 32
# Patch extracted: depth 128, height 80, width 0
# Patch extracted: depth 128, height 80, width 16
# Patch extracted: depth 128, height 80, width 32
# Patch extracted: depth 128, height 96, width 0
# Patch extracted: depth 128, height 96, width 16
# Patch extracted: depth 128, height 96, width 32
# Patch extracted: depth 128, height 112, width 0
# Patch extracted: depth 128, height 112, width 16
# Patch extracted: depth 128, height 112, width 32
# Patch extracted: depth 128, height 128, width 0
# Patch extracted: depth 128, height 128, width 16
# Patch extracted: depth 128, height 128, width 32
# Patch extracted: depth 128, height 144, width 0
# Patch extracted: depth 128, height 144, width 16
# Patch extracted: depth 128, height 144, width 32
# Patch extracted: depth 128, height 160, width 0
# Patch extracted: depth 128, height 160, width 16
# Patch extracted: depth 128, height 160, width 32
# Patch extracted: depth 128, height 176, width 0
# Patch extracted: depth 128, height 176, width 16
# Patch extracted: depth 128, height 176, width 32
# Patch extracted: depth 144, height 0, width 0
# Patch extracted: depth 144, height 0, width 16
# Patch extracted: depth 144, height 0, width 32
# Patch extracted: depth 144, height 16, width 0
# Patch extracted: depth 144, height 16, width 16
# Patch extracted: depth 144, height 16, width 32
# Patch extracted: depth 144, height 32, width 0
# Patch extracted: depth 144, height 32, width 16
# Patch extracted: depth 144, height 32, width 32
# Patch extracted: depth 144, height 48, width 0
# Patch extracted: depth 144, height 48, width 16
# Patch extracted: depth 144, height 48, width 32
# Patch extracted: depth 144, height 64, width 0
# Patch extracted: depth 144, height 64, width 16
# Patch extracted: depth 144, height 64, width 32
# Patch extracted: depth 144, height 80, width 0
# Patch extracted: depth 144, height 80, width 16
# Patch extracted: depth 144, height 80, width 32
# Patch extracted: depth 144, height 96, width 0
# Patch extracted: depth 144, height 96, width 16
# Patch extracted: depth 144, height 96, width 32
# Patch extracted: depth 144, height 112, width 0
# Patch extracted: depth 144, height 112, width 16
# Patch extracted: depth 144, height 112, width 32
# Patch extracted: depth 144, height 128, width 0
# Patch extracted: depth 144, height 128, width 16
# Patch extracted: depth 144, height 128, width 32
# Patch extracted: depth 144, height 144, width 0
# Patch extracted: depth 144, height 144, width 16
# Patch extracted: depth 144, height 144, width 32
# Patch extracted: depth 144, height 160, width 0
# Patch extracted: depth 144, height 160, width 16
# Patch extracted: depth 144, height 160, width 32
# Patch extracted: depth 144, height 176, width 0
# Patch extracted: depth 144, height 176, width 16
# Patch extracted: depth 144, height 176, width 32
# Patch extracted: depth 160, height 0, width 0
# Patch extracted: depth 160, height 0, width 16
# Patch extracted: depth 160, height 0, width 32
# Patch extracted: depth 160, height 16, width 0
# Patch extracted: depth 160, height 16, width 16
# Patch extracted: depth 160, height 16, width 32
# Patch extracted: depth 160, height 32, width 0
# Patch extracted: depth 160, height 32, width 16
# Patch extracted: depth 160, height 32, width 32
# Patch extracted: depth 160, height 48, width 0
# Patch extracted: depth 160, height 48, width 16
# Patch extracted: depth 160, height 48, width 32
# Patch extracted: depth 160, height 64, width 0
# Patch extracted: depth 160, height 64, width 16
# Patch extracted: depth 160, height 64, width 32
# Patch extracted: depth 160, height 80, width 0
# Patch extracted: depth 160, height 80, width 16
# Patch extracted: depth 160, height 80, width 32
# Patch extracted: depth 160, height 96, width 0
# Patch extracted: depth 160, height 96, width 16
# Patch extracted: depth 160, height 96, width 32
# Patch extracted: depth 160, height 112, width 0
# Patch extracted: depth 160, height 112, width 16
# Patch extracted: depth 160, height 112, width 32
# Patch extracted: depth 160, height 128, width 0
# Patch extracted: depth 160, height 128, width 16
# Patch extracted: depth 160, height 128, width 32
# Patch extracted: depth 160, height 144, width 0
# Patch extracted: depth 160, height 144, width 16
# Patch extracted: depth 160, height 144, width 32
# Patch extracted: depth 160, height 160, width 0
# Patch extracted: depth 160, height 160, width 16
# Patch extracted: depth 160, height 160, width 32
# Patch extracted: depth 160, height 176, width 0
# Patch extracted: depth 160, height 176, width 16
# Patch extracted: depth 160, height 176, width 32
# Patch extracted: depth 176, height 0, width 0
# Patch extracted: depth 176, height 0, width 16
# Patch extracted: depth 176, height 0, width 32
# Patch extracted: depth 176, height 16, width 0
# Patch extracted: depth 176, height 16, width 16
# Patch extracted: depth 176, height 16, width 32
# Patch extracted: depth 176, height 32, width 0
# Patch extracted: depth 176, height 32, width 16
# Patch extracted: depth 176, height 32, width 32
# Patch extracted: depth 176, height 48, width 0
# Patch extracted: depth 176, height 48, width 16
# Patch extracted: depth 176, height 48, width 32
# Patch extracted: depth 176, height 64, width 0
# Patch extracted: depth 176, height 64, width 16
# Patch extracted: depth 176, height 64, width 32
# Patch extracted: depth 176, height 80, width 0
# Patch extracted: depth 176, height 80, width 16
# Patch extracted: depth 176, height 80, width 32
# Patch extracted: depth 176, height 96, width 0
# Patch extracted: depth 176, height 96, width 16
# Patch extracted: depth 176, height 96, width 32
# Patch extracted: depth 176, height 112, width 0
# Patch extracted: depth 176, height 112, width 16
# Patch extracted: depth 176, height 112, width 32
# Patch extracted: depth 176, height 128, width 0
# Patch extracted: depth 176, height 128, width 16
# Patch extracted: depth 176, height 128, width 32
# Patch extracted: depth 176, height 144, width 0
# Patch extracted: depth 176, height 144, width 16
# Patch extracted: depth 176, height 144, width 32
# Patch extracted: depth 176, height 160, width 0
# Patch extracted: depth 176, height 160, width 16
# Patch extracted: depth 176, height 160, width 32
# Patch extracted: depth 176, height 176, width 0
# Patch extracted: depth 176, height 176, width 16
# Patch extracted: depth 176, height 176, width 32
# Total patches extracted: 432
#  - Number of image patches extracted: 432
#  - Number of mask patches extracted: 432
# Checking for files in subfolder: /kaggle/working/training_dataset/14
#  - T1 path: /kaggle/working/training_dataset/14/pre/T1.nii/T1.nii
#  - IR path: /kaggle/working/training_dataset/14/pre/IR.nii/IR.nii
#  - FLAIR path: /kaggle/working/training_dataset/14/pre/FLAIR.nii/FLAIR.nii
#  - Segmentation path: /kaggle/working/training_dataset/14/segm.nii/segm.nii
#  - T1 shape after loading: (256, 256, 192)
#  - IR shape after loading: (240, 240, 48)
#  - FLAIR shape after loading: (240, 240, 48)
#  - Segmentation shape after loading: (240, 240, 48)
#  - T1 shape: (240, 240, 48)
#  - IR shape: (240, 240, 48)
#  - FLAIR shape: (240, 240, 48)
#  - Segmentation shape: (240, 240, 48)
# Stride: 16, Patch size: (64, 64, 16)
# Depth: 240, Height: 240, Width: 48
# Patch extracted: depth 0, height 0, width 0
# Patch extracted: depth 0, height 0, width 16
# Patch extracted: depth 0, height 0, width 32
# Patch extracted: depth 0, height 16, width 0
# Patch extracted: depth 0, height 16, width 16
# Patch extracted: depth 0, height 16, width 32
# Patch extracted: depth 0, height 32, width 0
# Patch extracted: depth 0, height 32, width 16
# Patch extracted: depth 0, height 32, width 32
# Patch extracted: depth 0, height 48, width 0
# Patch extracted: depth 0, height 48, width 16
# Patch extracted: depth 0, height 48, width 32
# Patch extracted: depth 0, height 64, width 0
# Patch extracted: depth 0, height 64, width 16
# Patch extracted: depth 0, height 64, width 32
# Patch extracted: depth 0, height 80, width 0
# Patch extracted: depth 0, height 80, width 16
# Patch extracted: depth 0, height 80, width 32
# Patch extracted: depth 0, height 96, width 0
# Patch extracted: depth 0, height 96, width 16
# Patch extracted: depth 0, height 96, width 32
# Patch extracted: depth 0, height 112, width 0
# Patch extracted: depth 0, height 112, width 16
# Patch extracted: depth 0, height 112, width 32
# Patch extracted: depth 0, height 128, width 0
# Patch extracted: depth 0, height 128, width 16
# Patch extracted: depth 0, height 128, width 32
# Patch extracted: depth 0, height 144, width 0
# Patch extracted: depth 0, height 144, width 16
# Patch extracted: depth 0, height 144, width 32
# Patch extracted: depth 0, height 160, width 0
# Patch extracted: depth 0, height 160, width 16
# Patch extracted: depth 0, height 160, width 32
# Patch extracted: depth 0, height 176, width 0
# Patch extracted: depth 0, height 176, width 16
# Patch extracted: depth 0, height 176, width 32
# Patch extracted: depth 16, height 0, width 0
# Patch extracted: depth 16, height 0, width 16
# Patch extracted: depth 16, height 0, width 32
# Patch extracted: depth 16, height 16, width 0
# Patch extracted: depth 16, height 16, width 16
# Patch extracted: depth 16, height 16, width 32
# Patch extracted: depth 16, height 32, width 0
# Patch extracted: depth 16, height 32, width 16
# Patch extracted: depth 16, height 32, width 32
# Patch extracted: depth 16, height 48, width 0
# Patch extracted: depth 16, height 48, width 16
# Patch extracted: depth 16, height 48, width 32
# Patch extracted: depth 16, height 64, width 0
# Patch extracted: depth 16, height 64, width 16
# Patch extracted: depth 16, height 64, width 32
# Patch extracted: depth 16, height 80, width 0
# Patch extracted: depth 16, height 80, width 16
# Patch extracted: depth 16, height 80, width 32
# Patch extracted: depth 16, height 96, width 0
# Patch extracted: depth 16, height 96, width 16
# Patch extracted: depth 16, height 96, width 32
# Patch extracted: depth 16, height 112, width 0
# Patch extracted: depth 16, height 112, width 16
# Patch extracted: depth 16, height 112, width 32
# Patch extracted: depth 16, height 128, width 0
# Patch extracted: depth 16, height 128, width 16
# Patch extracted: depth 16, height 128, width 32
# Patch extracted: depth 16, height 144, width 0
# Patch extracted: depth 16, height 144, width 16
# Patch extracted: depth 16, height 144, width 32
# Patch extracted: depth 16, height 160, width 0
# Patch extracted: depth 16, height 160, width 16
# Patch extracted: depth 16, height 160, width 32
# Patch extracted: depth 16, height 176, width 0
# Patch extracted: depth 16, height 176, width 16
# Patch extracted: depth 16, height 176, width 32
# Patch extracted: depth 32, height 0, width 0
# Patch extracted: depth 32, height 0, width 16
# Patch extracted: depth 32, height 0, width 32
# Patch extracted: depth 32, height 16, width 0
# Patch extracted: depth 32, height 16, width 16
# Patch extracted: depth 32, height 16, width 32
# Patch extracted: depth 32, height 32, width 0
# Patch extracted: depth 32, height 32, width 16
# Patch extracted: depth 32, height 32, width 32
# Patch extracted: depth 32, height 48, width 0
# Patch extracted: depth 32, height 48, width 16
# Patch extracted: depth 32, height 48, width 32
# Patch extracted: depth 32, height 64, width 0
# Patch extracted: depth 32, height 64, width 16
# Patch extracted: depth 32, height 64, width 32
# Patch extracted: depth 32, height 80, width 0
# Patch extracted: depth 32, height 80, width 16
# Patch extracted: depth 32, height 80, width 32
# Patch extracted: depth 32, height 96, width 0
# Patch extracted: depth 32, height 96, width 16
# Patch extracted: depth 32, height 96, width 32
# Patch extracted: depth 32, height 112, width 0
# Patch extracted: depth 32, height 112, width 16
# Patch extracted: depth 32, height 112, width 32
# Patch extracted: depth 32, height 128, width 0
# Patch extracted: depth 32, height 128, width 16
# Patch extracted: depth 32, height 128, width 32
# Patch extracted: depth 32, height 144, width 0
# Patch extracted: depth 32, height 144, width 16
# Patch extracted: depth 32, height 144, width 32
# Patch extracted: depth 32, height 160, width 0
# Patch extracted: depth 32, height 160, width 16
# Patch extracted: depth 32, height 160, width 32
# Patch extracted: depth 32, height 176, width 0
# Patch extracted: depth 32, height 176, width 16
# Patch extracted: depth 32, height 176, width 32
# Patch extracted: depth 48, height 0, width 0
# Patch extracted: depth 48, height 0, width 16
# Patch extracted: depth 48, height 0, width 32
# Patch extracted: depth 48, height 16, width 0
# Patch extracted: depth 48, height 16, width 16
# Patch extracted: depth 48, height 16, width 32
# Patch extracted: depth 48, height 32, width 0
# Patch extracted: depth 48, height 32, width 16
# Patch extracted: depth 48, height 32, width 32
# Patch extracted: depth 48, height 48, width 0
# Patch extracted: depth 48, height 48, width 16
# Patch extracted: depth 48, height 48, width 32
# Patch extracted: depth 48, height 64, width 0
# Patch extracted: depth 48, height 64, width 16
# Patch extracted: depth 48, height 64, width 32
# Patch extracted: depth 48, height 80, width 0
# Patch extracted: depth 48, height 80, width 16
# Patch extracted: depth 48, height 80, width 32
# Patch extracted: depth 48, height 96, width 0
# Patch extracted: depth 48, height 96, width 16
# Patch extracted: depth 48, height 96, width 32
# Patch extracted: depth 48, height 112, width 0
# Patch extracted: depth 48, height 112, width 16
# Patch extracted: depth 48, height 112, width 32
# Patch extracted: depth 48, height 128, width 0
# Patch extracted: depth 48, height 128, width 16
# Patch extracted: depth 48, height 128, width 32
# Patch extracted: depth 48, height 144, width 0
# Patch extracted: depth 48, height 144, width 16
# Patch extracted: depth 48, height 144, width 32
# Patch extracted: depth 48, height 160, width 0
# Patch extracted: depth 48, height 160, width 16
# Patch extracted: depth 48, height 160, width 32
# Patch extracted: depth 48, height 176, width 0
# Patch extracted: depth 48, height 176, width 16
# Patch extracted: depth 48, height 176, width 32
# Patch extracted: depth 64, height 0, width 0
# Patch extracted: depth 64, height 0, width 16
# Patch extracted: depth 64, height 0, width 32
# Patch extracted: depth 64, height 16, width 0
# Patch extracted: depth 64, height 16, width 16
# Patch extracted: depth 64, height 16, width 32
# Patch extracted: depth 64, height 32, width 0
# Patch extracted: depth 64, height 32, width 16
# Patch extracted: depth 64, height 32, width 32
# Patch extracted: depth 64, height 48, width 0
# Patch extracted: depth 64, height 48, width 16
# Patch extracted: depth 64, height 48, width 32
# Patch extracted: depth 64, height 64, width 0
# Patch extracted: depth 64, height 64, width 16
# Patch extracted: depth 64, height 64, width 32
# Patch extracted: depth 64, height 80, width 0
# Patch extracted: depth 64, height 80, width 16
# Patch extracted: depth 64, height 80, width 32
# Patch extracted: depth 64, height 96, width 0
# Patch extracted: depth 64, height 96, width 16
# Patch extracted: depth 64, height 96, width 32
# Patch extracted: depth 64, height 112, width 0
# Patch extracted: depth 64, height 112, width 16
# Patch extracted: depth 64, height 112, width 32
# Patch extracted: depth 64, height 128, width 0
# Patch extracted: depth 64, height 128, width 16
# Patch extracted: depth 64, height 128, width 32
# Patch extracted: depth 64, height 144, width 0
# Patch extracted: depth 64, height 144, width 16
# Patch extracted: depth 64, height 144, width 32
# Patch extracted: depth 64, height 160, width 0
# Patch extracted: depth 64, height 160, width 16
# Patch extracted: depth 64, height 160, width 32
# Patch extracted: depth 64, height 176, width 0
# Patch extracted: depth 64, height 176, width 16
# Patch extracted: depth 64, height 176, width 32
# Patch extracted: depth 80, height 0, width 0
# Patch extracted: depth 80, height 0, width 16
# Patch extracted: depth 80, height 0, width 32
# Patch extracted: depth 80, height 16, width 0
# Patch extracted: depth 80, height 16, width 16
# Patch extracted: depth 80, height 16, width 32
# Patch extracted: depth 80, height 32, width 0
# Patch extracted: depth 80, height 32, width 16
# Patch extracted: depth 80, height 32, width 32
# Patch extracted: depth 80, height 48, width 0
# Patch extracted: depth 80, height 48, width 16
# Patch extracted: depth 80, height 48, width 32
# Patch extracted: depth 80, height 64, width 0
# Patch extracted: depth 80, height 64, width 16
# Patch extracted: depth 80, height 64, width 32
# Patch extracted: depth 80, height 80, width 0
# Patch extracted: depth 80, height 80, width 16
# Patch extracted: depth 80, height 80, width 32
# Patch extracted: depth 80, height 96, width 0
# Patch extracted: depth 80, height 96, width 16
# Patch extracted: depth 80, height 96, width 32
# Patch extracted: depth 80, height 112, width 0
# Patch extracted: depth 80, height 112, width 16
# Patch extracted: depth 80, height 112, width 32
# Patch extracted: depth 80, height 128, width 0
# Patch extracted: depth 80, height 128, width 16
# Patch extracted: depth 80, height 128, width 32
# Patch extracted: depth 80, height 144, width 0
# Patch extracted: depth 80, height 144, width 16
# Patch extracted: depth 80, height 144, width 32
# Patch extracted: depth 80, height 160, width 0
# Patch extracted: depth 80, height 160, width 16
# Patch extracted: depth 80, height 160, width 32
# Patch extracted: depth 80, height 176, width 0
# Patch extracted: depth 80, height 176, width 16
# Patch extracted: depth 80, height 176, width 32
# Patch extracted: depth 96, height 0, width 0
# Patch extracted: depth 96, height 0, width 16
# Patch extracted: depth 96, height 0, width 32
# Patch extracted: depth 96, height 16, width 0
# Patch extracted: depth 96, height 16, width 16
# Patch extracted: depth 96, height 16, width 32
# Patch extracted: depth 96, height 32, width 0
# Patch extracted: depth 96, height 32, width 16
# Patch extracted: depth 96, height 32, width 32
# Patch extracted: depth 96, height 48, width 0
# Patch extracted: depth 96, height 48, width 16
# Patch extracted: depth 96, height 48, width 32
# Patch extracted: depth 96, height 64, width 0
# Patch extracted: depth 96, height 64, width 16
# Patch extracted: depth 96, height 64, width 32
# Patch extracted: depth 96, height 80, width 0
# Patch extracted: depth 96, height 80, width 16
# Patch extracted: depth 96, height 80, width 32
# Patch extracted: depth 96, height 96, width 0
# Patch extracted: depth 96, height 96, width 16
# Patch extracted: depth 96, height 96, width 32
# Patch extracted: depth 96, height 112, width 0
# Patch extracted: depth 96, height 112, width 16
# Patch extracted: depth 96, height 112, width 32
# Patch extracted: depth 96, height 128, width 0
# Patch extracted: depth 96, height 128, width 16
# Patch extracted: depth 96, height 128, width 32
# Patch extracted: depth 96, height 144, width 0
# Patch extracted: depth 96, height 144, width 16
# Patch extracted: depth 96, height 144, width 32
# Patch extracted: depth 96, height 160, width 0
# Patch extracted: depth 96, height 160, width 16
# Patch extracted: depth 96, height 160, width 32
# Patch extracted: depth 96, height 176, width 0
# Patch extracted: depth 96, height 176, width 16
# Patch extracted: depth 96, height 176, width 32
# Patch extracted: depth 112, height 0, width 0
# Patch extracted: depth 112, height 0, width 16
# Patch extracted: depth 112, height 0, width 32
# Patch extracted: depth 112, height 16, width 0
# Patch extracted: depth 112, height 16, width 16
# Patch extracted: depth 112, height 16, width 32
# Patch extracted: depth 112, height 32, width 0
# Patch extracted: depth 112, height 32, width 16
# Patch extracted: depth 112, height 32, width 32
# Patch extracted: depth 112, height 48, width 0
# Patch extracted: depth 112, height 48, width 16
# Patch extracted: depth 112, height 48, width 32
# Patch extracted: depth 112, height 64, width 0
# Patch extracted: depth 112, height 64, width 16
# Patch extracted: depth 112, height 64, width 32
# Patch extracted: depth 112, height 80, width 0
# Patch extracted: depth 112, height 80, width 16
# Patch extracted: depth 112, height 80, width 32
# Patch extracted: depth 112, height 96, width 0
# Patch extracted: depth 112, height 96, width 16
# Patch extracted: depth 112, height 96, width 32
# Patch extracted: depth 112, height 112, width 0
# Patch extracted: depth 112, height 112, width 16
# Patch extracted: depth 112, height 112, width 32
# Patch extracted: depth 112, height 128, width 0
# Patch extracted: depth 112, height 128, width 16
# Patch extracted: depth 112, height 128, width 32
# Patch extracted: depth 112, height 144, width 0
# Patch extracted: depth 112, height 144, width 16
# Patch extracted: depth 112, height 144, width 32
# Patch extracted: depth 112, height 160, width 0
# Patch extracted: depth 112, height 160, width 16
# Patch extracted: depth 112, height 160, width 32
# Patch extracted: depth 112, height 176, width 0
# Patch extracted: depth 112, height 176, width 16
# Patch extracted: depth 112, height 176, width 32
# Patch extracted: depth 128, height 0, width 0
# Patch extracted: depth 128, height 0, width 16
# Patch extracted: depth 128, height 0, width 32
# Patch extracted: depth 128, height 16, width 0
# Patch extracted: depth 128, height 16, width 16
# Patch extracted: depth 128, height 16, width 32
# Patch extracted: depth 128, height 32, width 0
# Patch extracted: depth 128, height 32, width 16
# Patch extracted: depth 128, height 32, width 32
# Patch extracted: depth 128, height 48, width 0
# Patch extracted: depth 128, height 48, width 16
# Patch extracted: depth 128, height 48, width 32
# Patch extracted: depth 128, height 64, width 0
# Patch extracted: depth 128, height 64, width 16
# Patch extracted: depth 128, height 64, width 32
# Patch extracted: depth 128, height 80, width 0
# Patch extracted: depth 128, height 80, width 16
# Patch extracted: depth 128, height 80, width 32
# Patch extracted: depth 128, height 96, width 0
# Patch extracted: depth 128, height 96, width 16
# Patch extracted: depth 128, height 96, width 32
# Patch extracted: depth 128, height 112, width 0
# Patch extracted: depth 128, height 112, width 16
# Patch extracted: depth 128, height 112, width 32
# Patch extracted: depth 128, height 128, width 0
# Patch extracted: depth 128, height 128, width 16
# Patch extracted: depth 128, height 128, width 32
# Patch extracted: depth 128, height 144, width 0
# Patch extracted: depth 128, height 144, width 16
# Patch extracted: depth 128, height 144, width 32
# Patch extracted: depth 128, height 160, width 0
# Patch extracted: depth 128, height 160, width 16
# Patch extracted: depth 128, height 160, width 32
# Patch extracted: depth 128, height 176, width 0
# Patch extracted: depth 128, height 176, width 16
# Patch extracted: depth 128, height 176, width 32
# Patch extracted: depth 144, height 0, width 0
# Patch extracted: depth 144, height 0, width 16
# Patch extracted: depth 144, height 0, width 32
# Patch extracted: depth 144, height 16, width 0
# Patch extracted: depth 144, height 16, width 16
# Patch extracted: depth 144, height 16, width 32
# Patch extracted: depth 144, height 32, width 0
# Patch extracted: depth 144, height 32, width 16
# Patch extracted: depth 144, height 32, width 32
# Patch extracted: depth 144, height 48, width 0
# Patch extracted: depth 144, height 48, width 16
# Patch extracted: depth 144, height 48, width 32
# Patch extracted: depth 144, height 64, width 0
# Patch extracted: depth 144, height 64, width 16
# Patch extracted: depth 144, height 64, width 32
# Patch extracted: depth 144, height 80, width 0
# Patch extracted: depth 144, height 80, width 16
# Patch extracted: depth 144, height 80, width 32
# Patch extracted: depth 144, height 96, width 0
# Patch extracted: depth 144, height 96, width 16
# Patch extracted: depth 144, height 96, width 32
# Patch extracted: depth 144, height 112, width 0
# Patch extracted: depth 144, height 112, width 16
# Patch extracted: depth 144, height 112, width 32
# Patch extracted: depth 144, height 128, width 0
# Patch extracted: depth 144, height 128, width 16
# Patch extracted: depth 144, height 128, width 32
# Patch extracted: depth 144, height 144, width 0
# Patch extracted: depth 144, height 144, width 16
# Patch extracted: depth 144, height 144, width 32
# Patch extracted: depth 144, height 160, width 0
# Patch extracted: depth 144, height 160, width 16
# Patch extracted: depth 144, height 160, width 32
# Patch extracted: depth 144, height 176, width 0
# Patch extracted: depth 144, height 176, width 16
# Patch extracted: depth 144, height 176, width 32
# Patch extracted: depth 160, height 0, width 0
# Patch extracted: depth 160, height 0, width 16
# Patch extracted: depth 160, height 0, width 32
# Patch extracted: depth 160, height 16, width 0
# Patch extracted: depth 160, height 16, width 16
# Patch extracted: depth 160, height 16, width 32
# Patch extracted: depth 160, height 32, width 0
# Patch extracted: depth 160, height 32, width 16
# Patch extracted: depth 160, height 32, width 32
# Patch extracted: depth 160, height 48, width 0
# Patch extracted: depth 160, height 48, width 16
# Patch extracted: depth 160, height 48, width 32
# Patch extracted: depth 160, height 64, width 0
# Patch extracted: depth 160, height 64, width 16
# Patch extracted: depth 160, height 64, width 32
# Patch extracted: depth 160, height 80, width 0
# Patch extracted: depth 160, height 80, width 16
# Patch extracted: depth 160, height 80, width 32
# Patch extracted: depth 160, height 96, width 0
# Patch extracted: depth 160, height 96, width 16
# Patch extracted: depth 160, height 96, width 32
# Patch extracted: depth 160, height 112, width 0
# Patch extracted: depth 160, height 112, width 16
# Patch extracted: depth 160, height 112, width 32
# Patch extracted: depth 160, height 128, width 0
# Patch extracted: depth 160, height 128, width 16
# Patch extracted: depth 160, height 128, width 32
# Patch extracted: depth 160, height 144, width 0
# Patch extracted: depth 160, height 144, width 16
# Patch extracted: depth 160, height 144, width 32
# Patch extracted: depth 160, height 160, width 0
# Patch extracted: depth 160, height 160, width 16
# Patch extracted: depth 160, height 160, width 32
# Patch extracted: depth 160, height 176, width 0
# Patch extracted: depth 160, height 176, width 16
# Patch extracted: depth 160, height 176, width 32
# Patch extracted: depth 176, height 0, width 0
# Patch extracted: depth 176, height 0, width 16
# Patch extracted: depth 176, height 0, width 32
# Patch extracted: depth 176, height 16, width 0
# Patch extracted: depth 176, height 16, width 16
# Patch extracted: depth 176, height 16, width 32
# Patch extracted: depth 176, height 32, width 0
# Patch extracted: depth 176, height 32, width 16
# Patch extracted: depth 176, height 32, width 32
# Patch extracted: depth 176, height 48, width 0
# Patch extracted: depth 176, height 48, width 16
# Patch extracted: depth 176, height 48, width 32
# Patch extracted: depth 176, height 64, width 0
# Patch extracted: depth 176, height 64, width 16
# Patch extracted: depth 176, height 64, width 32
# Patch extracted: depth 176, height 80, width 0
# Patch extracted: depth 176, height 80, width 16
# Patch extracted: depth 176, height 80, width 32
# Patch extracted: depth 176, height 96, width 0
# Patch extracted: depth 176, height 96, width 16
# Patch extracted: depth 176, height 96, width 32
# Patch extracted: depth 176, height 112, width 0
# Patch extracted: depth 176, height 112, width 16
# Patch extracted: depth 176, height 112, width 32
# Patch extracted: depth 176, height 128, width 0
# Patch extracted: depth 176, height 128, width 16
# Patch extracted: depth 176, height 128, width 32
# Patch extracted: depth 176, height 144, width 0
# Patch extracted: depth 176, height 144, width 16
# Patch extracted: depth 176, height 144, width 32
# Patch extracted: depth 176, height 160, width 0
# Patch extracted: depth 176, height 160, width 16
# Patch extracted: depth 176, height 160, width 32
# Patch extracted: depth 176, height 176, width 0
# Patch extracted: depth 176, height 176, width 16
# Patch extracted: depth 176, height 176, width 32
# Total patches extracted: 432
#  - Number of image patches extracted: 432
#  - Number of mask patches extracted: 432
# Checking for files in subfolder: /kaggle/working/training_dataset/27
#  - T1 path: /kaggle/working/training_dataset/27/pre/T1.nii/T1.nii
#  - IR path: /kaggle/working/training_dataset/27/pre/IR.nii/IR.nii
#  - FLAIR path: /kaggle/working/training_dataset/27/pre/FLAIR.nii/FLAIR.nii
#  - Segmentation path: /kaggle/working/training_dataset/27/segm.nii/segm.nii
#  - T1 shape after loading: (256, 256, 192)
#  - IR shape after loading: (240, 240, 48)
#  - FLAIR shape after loading: (240, 240, 48)
#  - Segmentation shape after loading: (240, 240, 48)
#  - T1 shape: (240, 240, 48)
#  - IR shape: (240, 240, 48)
#  - FLAIR shape: (240, 240, 48)
#  - Segmentation shape: (240, 240, 48)
# Stride: 16, Patch size: (64, 64, 16)
# Depth: 240, Height: 240, Width: 48
# Patch extracted: depth 0, height 0, width 0
# Patch extracted: depth 0, height 0, width 16
# Patch extracted: depth 0, height 0, width 32
# Patch extracted: depth 0, height 16, width 0
# Patch extracted: depth 0, height 16, width 16
# Patch extracted: depth 0, height 16, width 32
# Patch extracted: depth 0, height 32, width 0
# Patch extracted: depth 0, height 32, width 16
# Patch extracted: depth 0, height 32, width 32
# Patch extracted: depth 0, height 48, width 0
# Patch extracted: depth 0, height 48, width 16
# Patch extracted: depth 0, height 48, width 32
# Patch extracted: depth 0, height 64, width 0
# Patch extracted: depth 0, height 64, width 16
# Patch extracted: depth 0, height 64, width 32
# Patch extracted: depth 0, height 80, width 0
# Patch extracted: depth 0, height 80, width 16
# Patch extracted: depth 0, height 80, width 32
# Patch extracted: depth 0, height 96, width 0
# Patch extracted: depth 0, height 96, width 16
# Patch extracted: depth 0, height 96, width 32
# Patch extracted: depth 0, height 112, width 0
# Patch extracted: depth 0, height 112, width 16
# Patch extracted: depth 0, height 112, width 32
# Patch extracted: depth 0, height 128, width 0
# Patch extracted: depth 0, height 128, width 16
# Patch extracted: depth 0, height 128, width 32
# Patch extracted: depth 0, height 144, width 0
# Patch extracted: depth 0, height 144, width 16
# Patch extracted: depth 0, height 144, width 32
# Patch extracted: depth 0, height 160, width 0
# Patch extracted: depth 0, height 160, width 16
# Patch extracted: depth 0, height 160, width 32
# Patch extracted: depth 0, height 176, width 0
# Patch extracted: depth 0, height 176, width 16
# Patch extracted: depth 0, height 176, width 32
# Patch extracted: depth 16, height 0, width 0
# Patch extracted: depth 16, height 0, width 16
# Patch extracted: depth 16, height 0, width 32
# Patch extracted: depth 16, height 16, width 0
# Patch extracted: depth 16, height 16, width 16
# Patch extracted: depth 16, height 16, width 32
# Patch extracted: depth 16, height 32, width 0
# Patch extracted: depth 16, height 32, width 16
# Patch extracted: depth 16, height 32, width 32
# Patch extracted: depth 16, height 48, width 0
# Patch extracted: depth 16, height 48, width 16
# Patch extracted: depth 16, height 48, width 32
# Patch extracted: depth 16, height 64, width 0
# Patch extracted: depth 16, height 64, width 16
# Patch extracted: depth 16, height 64, width 32
# Patch extracted: depth 16, height 80, width 0
# Patch extracted: depth 16, height 80, width 16
# Patch extracted: depth 16, height 80, width 32
# Patch extracted: depth 16, height 96, width 0
# Patch extracted: depth 16, height 96, width 16
# Patch extracted: depth 16, height 96, width 32
# Patch extracted: depth 16, height 112, width 0
# Patch extracted: depth 16, height 112, width 16
# Patch extracted: depth 16, height 112, width 32
# Patch extracted: depth 16, height 128, width 0
# Patch extracted: depth 16, height 128, width 16
# Patch extracted: depth 16, height 128, width 32
# Patch extracted: depth 16, height 144, width 0
# Patch extracted: depth 16, height 144, width 16
# Patch extracted: depth 16, height 144, width 32
# Patch extracted: depth 16, height 160, width 0
# Patch extracted: depth 16, height 160, width 16
# Patch extracted: depth 16, height 160, width 32
# Patch extracted: depth 16, height 176, width 0
# Patch extracted: depth 16, height 176, width 16
# Patch extracted: depth 16, height 176, width 32
# Patch extracted: depth 32, height 0, width 0
# Patch extracted: depth 32, height 0, width 16
# Patch extracted: depth 32, height 0, width 32
# Patch extracted: depth 32, height 16, width 0
# Patch extracted: depth 32, height 16, width 16
# Patch extracted: depth 32, height 16, width 32
# Patch extracted: depth 32, height 32, width 0
# Patch extracted: depth 32, height 32, width 16
# Patch extracted: depth 32, height 32, width 32
# Patch extracted: depth 32, height 48, width 0
# Patch extracted: depth 32, height 48, width 16
# Patch extracted: depth 32, height 48, width 32
# Patch extracted: depth 32, height 64, width 0
# Patch extracted: depth 32, height 64, width 16
# Patch extracted: depth 32, height 64, width 32
# Patch extracted: depth 32, height 80, width 0
# Patch extracted: depth 32, height 80, width 16
# Patch extracted: depth 32, height 80, width 32
# Patch extracted: depth 32, height 96, width 0
# Patch extracted: depth 32, height 96, width 16
# Patch extracted: depth 32, height 96, width 32
# Patch extracted: depth 32, height 112, width 0
# Patch extracted: depth 32, height 112, width 16
# Patch extracted: depth 32, height 112, width 32
# Patch extracted: depth 32, height 128, width 0
# Patch extracted: depth 32, height 128, width 16
# Patch extracted: depth 32, height 128, width 32
# Patch extracted: depth 32, height 144, width 0
# ...
# Patch extracted: depth 32, height 144, width 0
# Patch extracted: depth 32, height 144, width 16
# Patch extracted: depth 32, height 144, width 32
# Patch extracted: depth 32, height 160, width 0
# Patch extracted: depth 32, height 160, width 16
# Patch extracted: depth 32, height 160, width 32
# Patch extracted: depth 32, height 176, width 0
# Patch extracted: depth 32, height 176, width 16
# Patch extracted: depth 32, height 176, width 32
# Patch extracted: depth 48, height 0, width 0
# Patch extracted: depth 48, height 0, width 16
# Patch extracted: depth 48, height 0, width 32
# Patch extracted: depth 48, height 16, width 0
# Patch extracted: depth 48, height 16, width 16
# Patch extracted: depth 48, height 16, width 32
# Patch extracted: depth 48, height 32, width 0
# Patch extracted: depth 48, height 32, width 16
# Patch extracted: depth 48, height 32, width 32
# Patch extracted: depth 48, height 48, width 0
# Patch extracted: depth 48, height 48, width 16
# Patch extracted: depth 48, height 48, width 32
# Patch extracted: depth 48, height 64, width 0
# Patch extracted: depth 48, height 64, width 16
# Patch extracted: depth 48, height 64, width 32
# Patch extracted: depth 48, height 80, width 0
# Patch extracted: depth 48, height 80, width 16
# Patch extracted: depth 48, height 80, width 32
# Patch extracted: depth 48, height 96, width 0
# Patch extracted: depth 48, height 96, width 16
# Patch extracted: depth 48, height 96, width 32
# Patch extracted: depth 48, height 112, width 0
# Patch extracted: depth 48, height 112, width 16
# Patch extracted: depth 48, height 112, width 32
# Patch extracted: depth 48, height 128, width 0
# Patch extracted: depth 48, height 128, width 16
# Patch extracted: depth 48, height 128, width 32
# Patch extracted: depth 48, height 144, width 0
# Patch extracted: depth 48, height 144, width 16
# Patch extracted: depth 48, height 144, width 32
# Patch extracted: depth 48, height 160, width 0
# Patch extracted: depth 48, height 160, width 16
# Patch extracted: depth 48, height 160, width 32
# Patch extracted: depth 48, height 176, width 0
# Patch extracted: depth 48, height 176, width 16
# Patch extracted: depth 48, height 176, width 32
# Patch extracted: depth 64, height 0, width 0
# Patch extracted: depth 64, height 0, width 16
# Patch extracted: depth 64, height 0, width 32
# Patch extracted: depth 64, height 16, width 0
# Patch extracted: depth 64, height 16, width 16
# Patch extracted: depth 64, height 16, width 32
# Patch extracted: depth 64, height 32, width 0
# Patch extracted: depth 64, height 32, width 16
# Patch extracted: depth 64, height 32, width 32
# Patch extracted: depth 64, height 48, width 0
# Patch extracted: depth 64, height 48, width 16
# Patch extracted: depth 64, height 48, width 32
# Patch extracted: depth 64, height 64, width 0
# Patch extracted: depth 64, height 64, width 16
# Patch extracted: depth 64, height 64, width 32
# Patch extracted: depth 64, height 80, width 0
# Patch extracted: depth 64, height 80, width 16
# Patch extracted: depth 64, height 80, width 32
# Patch extracted: depth 64, height 96, width 0
# Patch extracted: depth 64, height 96, width 16
# Patch extracted: depth 64, height 96, width 32
# Patch extracted: depth 64, height 112, width 0
# Patch extracted: depth 64, height 112, width 16
# Patch extracted: depth 64, height 112, width 32
# Patch extracted: depth 64, height 128, width 0
# Patch extracted: depth 64, height 128, width 16
# Patch extracted: depth 64, height 128, width 32
# Patch extracted: depth 64, height 144, width 0
# Patch extracted: depth 64, height 144, width 16
# Patch extracted: depth 64, height 144, width 32
# Patch extracted: depth 64, height 160, width 0
# Patch extracted: depth 64, height 160, width 16
# Patch extracted: depth 64, height 160, width 32
# Patch extracted: depth 64, height 176, width 0
# Patch extracted: depth 64, height 176, width 16
# Patch extracted: depth 64, height 176, width 32
# Patch extracted: depth 80, height 0, width 0
# Patch extracted: depth 80, height 0, width 16
# Patch extracted: depth 80, height 0, width 32
# Patch extracted: depth 80, height 16, width 0
# Patch extracted: depth 80, height 16, width 16
# Patch extracted: depth 80, height 16, width 32
# Patch extracted: depth 80, height 32, width 0
# Patch extracted: depth 80, height 32, width 16
# Patch extracted: depth 80, height 32, width 32
# Patch extracted: depth 80, height 48, width 0
# Patch extracted: depth 80, height 48, width 16
# Patch extracted: depth 80, height 48, width 32
# Patch extracted: depth 80, height 64, width 0
# Patch extracted: depth 80, height 64, width 16
# Patch extracted: depth 80, height 64, width 32
# Patch extracted: depth 80, height 80, width 0
# Patch extracted: depth 80, height 80, width 16
# Patch extracted: depth 80, height 80, width 32
# Patch extracted: depth 80, height 96, width 0
# Patch extracted: depth 80, height 96, width 16
# Patch extracted: depth 80, height 96, width 32
# Patch extracted: depth 80, height 112, width 0
# Patch extracted: depth 80, height 112, width 16
# Patch extracted: depth 80, height 112, width 32
# Patch extracted: depth 80, height 128, width 0
# Patch extracted: depth 80, height 128, width 16
# Patch extracted: depth 80, height 128, width 32
# Patch extracted: depth 80, height 144, width 0
# Patch extracted: depth 80, height 144, width 16
# Patch extracted: depth 80, height 144, width 32
# Patch extracted: depth 80, height 160, width 0
# Patch extracted: depth 80, height 160, width 16
# Patch extracted: depth 80, height 160, width 32
# Patch extracted: depth 80, height 176, width 0
# Patch extracted: depth 80, height 176, width 16
# Patch extracted: depth 80, height 176, width 32
# Patch extracted: depth 96, height 0, width 0
# Patch extracted: depth 96, height 0, width 16
# Patch extracted: depth 96, height 0, width 32
# Patch extracted: depth 96, height 16, width 0
# Patch extracted: depth 96, height 16, width 16
# Patch extracted: depth 96, height 16, width 32
# Patch extracted: depth 96, height 32, width 0
# Patch extracted: depth 96, height 32, width 16
# Patch extracted: depth 96, height 32, width 32
# Patch extracted: depth 96, height 48, width 0
# Patch extracted: depth 96, height 48, width 16
# Patch extracted: depth 96, height 48, width 32
# Patch extracted: depth 96, height 64, width 0
# Patch extracted: depth 96, height 64, width 16
# Patch extracted: depth 96, height 64, width 32
# Patch extracted: depth 96, height 80, width 0
# Patch extracted: depth 96, height 80, width 16
# Patch extracted: depth 96, height 80, width 32
# Patch extracted: depth 96, height 96, width 0
# Patch extracted: depth 96, height 96, width 16
# Patch extracted: depth 96, height 96, width 32
# Patch extracted: depth 96, height 112, width 0
# Patch extracted: depth 96, height 112, width 16
# Patch extracted: depth 96, height 112, width 32
# Patch extracted: depth 96, height 128, width 0
# Patch extracted: depth 96, height 128, width 16
# Patch extracted: depth 96, height 128, width 32
# Patch extracted: depth 96, height 144, width 0
# Patch extracted: depth 96, height 144, width 16
# Patch extracted: depth 96, height 144, width 32
# Patch extracted: depth 96, height 160, width 0
# Patch extracted: depth 96, height 160, width 16
# Patch extracted: depth 96, height 160, width 32
# Patch extracted: depth 96, height 176, width 0
# Patch extracted: depth 96, height 176, width 16
# Patch extracted: depth 96, height 176, width 32
# Patch extracted: depth 112, height 0, width 0
# Patch extracted: depth 112, height 0, width 16
# Patch extracted: depth 112, height 0, width 32
# Patch extracted: depth 112, height 16, width 0
# Patch extracted: depth 112, height 16, width 16
# Patch extracted: depth 112, height 16, width 32
# Patch extracted: depth 112, height 32, width 0
# Patch extracted: depth 112, height 32, width 16
# Patch extracted: depth 112, height 32, width 32
# Patch extracted: depth 112, height 48, width 0
# Patch extracted: depth 112, height 48, width 16
# Patch extracted: depth 112, height 48, width 32
# Patch extracted: depth 112, height 64, width 0
# Patch extracted: depth 112, height 64, width 16
# Patch extracted: depth 112, height 64, width 32
# Patch extracted: depth 112, height 80, width 0
# Patch extracted: depth 112, height 80, width 16
# Patch extracted: depth 112, height 80, width 32
# Patch extracted: depth 112, height 96, width 0
# Patch extracted: depth 112, height 96, width 16
# Patch extracted: depth 112, height 96, width 32
# Patch extracted: depth 112, height 112, width 0
# Patch extracted: depth 112, height 112, width 16
# Patch extracted: depth 112, height 112, width 32
# Patch extracted: depth 112, height 128, width 0
# Patch extracted: depth 112, height 128, width 16
# Patch extracted: depth 112, height 128, width 32
# Patch extracted: depth 112, height 144, width 0
# Patch extracted: depth 112, height 144, width 16
# Patch extracted: depth 112, height 144, width 32
# Patch extracted: depth 112, height 160, width 0
# Patch extracted: depth 112, height 160, width 16
# Patch extracted: depth 112, height 160, width 32
# Patch extracted: depth 112, height 176, width 0
# Patch extracted: depth 112, height 176, width 16
# Patch extracted: depth 112, height 176, width 32
# Patch extracted: depth 128, height 0, width 0
# Patch extracted: depth 128, height 0, width 16
# Patch extracted: depth 128, height 0, width 32
# Patch extracted: depth 128, height 16, width 0
# Patch extracted: depth 128, height 16, width 16
# Patch extracted: depth 128, height 16, width 32
# Patch extracted: depth 128, height 32, width 0
# Patch extracted: depth 128, height 32, width 16
# Patch extracted: depth 128, height 32, width 32
# Patch extracted: depth 128, height 48, width 0
# Patch extracted: depth 128, height 48, width 16
# Patch extracted: depth 128, height 48, width 32
# Patch extracted: depth 128, height 64, width 0
# Patch extracted: depth 128, height 64, width 16
# Patch extracted: depth 128, height 64, width 32
# Patch extracted: depth 128, height 80, width 0
# Patch extracted: depth 128, height 80, width 16
# Patch extracted: depth 128, height 80, width 32
# Patch extracted: depth 128, height 96, width 0
# Patch extracted: depth 128, height 96, width 16
# Patch extracted: depth 128, height 96, width 32
# Patch extracted: depth 128, height 112, width 0
# Patch extracted: depth 128, height 112, width 16
# Patch extracted: depth 128, height 112, width 32
# Patch extracted: depth 128, height 128, width 0
# Patch extracted: depth 128, height 128, width 16
# Patch extracted: depth 128, height 128, width 32
# Patch extracted: depth 128, height 144, width 0
# Patch extracted: depth 128, height 144, width 16
# Patch extracted: depth 128, height 144, width 32
# Patch extracted: depth 128, height 160, width 0
# Patch extracted: depth 128, height 160, width 16
# Patch extracted: depth 128, height 160, width 32
# Patch extracted: depth 128, height 176, width 0
# Patch extracted: depth 128, height 176, width 16
# Patch extracted: depth 128, height 176, width 32
# Patch extracted: depth 144, height 0, width 0
# Patch extracted: depth 144, height 0, width 16
# Patch extracted: depth 144, height 0, width 32
# Patch extracted: depth 144, height 16, width 0
# Patch extracted: depth 144, height 16, width 16
# Patch extracted: depth 144, height 16, width 32
# Patch extracted: depth 144, height 32, width 0
# Patch extracted: depth 144, height 32, width 16
# Patch extracted: depth 144, height 32, width 32
# Patch extracted: depth 144, height 48, width 0
# Patch extracted: depth 144, height 48, width 16
# Patch extracted: depth 144, height 48, width 32
# Patch extracted: depth 144, height 64, width 0
# Patch extracted: depth 144, height 64, width 16
# Patch extracted: depth 144, height 64, width 32
# Patch extracted: depth 144, height 80, width 0
# Patch extracted: depth 144, height 80, width 16
# Patch extracted: depth 144, height 80, width 32
# Patch extracted: depth 144, height 96, width 0
# Patch extracted: depth 144, height 96, width 16
# Patch extracted: depth 144, height 96, width 32
# Patch extracted: depth 144, height 112, width 0
# Patch extracted: depth 144, height 112, width 16
# Patch extracted: depth 144, height 112, width 32
# Patch extracted: depth 144, height 128, width 0
# Patch extracted: depth 144, height 128, width 16
# Patch extracted: depth 144, height 128, width 32
# Patch extracted: depth 144, height 144, width 0
# Patch extracted: depth 144, height 144, width 16
# Patch extracted: depth 144, height 144, width 32
# Patch extracted: depth 144, height 160, width 0
# Patch extracted: depth 144, height 160, width 16
# Patch extracted: depth 144, height 160, width 32
# Patch extracted: depth 144, height 176, width 0
# Patch extracted: depth 144, height 176, width 16
# Patch extracted: depth 144, height 176, width 32
# Patch extracted: depth 160, height 0, width 0
# Patch extracted: depth 160, height 0, width 16
# Patch extracted: depth 160, height 0, width 32
# Patch extracted: depth 160, height 16, width 0
# Patch extracted: depth 160, height 16, width 16
# Patch extracted: depth 160, height 16, width 32
# Patch extracted: depth 160, height 32, width 0
# Patch extracted: depth 160, height 32, width 16
# Patch extracted: depth 160, height 32, width 32
# Patch extracted: depth 160, height 48, width 0
# Patch extracted: depth 160, height 48, width 16
# Patch extracted: depth 160, height 48, width 32
# Patch extracted: depth 160, height 64, width 0
# Patch extracted: depth 160, height 64, width 16
# Patch extracted: depth 160, height 64, width 32
# Patch extracted: depth 160, height 80, width 0
# Patch extracted: depth 160, height 80, width 16
# Patch extracted: depth 160, height 80, width 32
# Patch extracted: depth 160, height 96, width 0
# Patch extracted: depth 160, height 96, width 16
# Patch extracted: depth 160, height 96, width 32
# Patch extracted: depth 160, height 112, width 0
# Patch extracted: depth 160, height 112, width 16
# Patch extracted: depth 160, height 112, width 32
# Patch extracted: depth 160, height 128, width 0
# Patch extracted: depth 160, height 128, width 16
# Patch extracted: depth 160, height 128, width 32
# Patch extracted: depth 160, height 144, width 0
# Patch extracted: depth 160, height 144, width 16
# Patch extracted: depth 160, height 144, width 32
# Patch extracted: depth 160, height 160, width 0
# Patch extracted: depth 160, height 160, width 16
# Patch extracted: depth 160, height 160, width 32
# Patch extracted: depth 160, height 176, width 0
# Patch extracted: depth 160, height 176, width 16
# Patch extracted: depth 160, height 176, width 32
# Patch extracted: depth 176, height 0, width 0
# Patch extracted: depth 176, height 0, width 16
# Patch extracted: depth 176, height 0, width 32
# Patch extracted: depth 176, height 16, width 0
# Patch extracted: depth 176, height 16, width 16
# Patch extracted: depth 176, height 16, width 32
# Patch extracted: depth 176, height 32, width 0
# Patch extracted: depth 176, height 32, width 16
# Patch extracted: depth 176, height 32, width 32
# Patch extracted: depth 176, height 48, width 0
# Patch extracted: depth 176, height 48, width 16
# Patch extracted: depth 176, height 48, width 32
# Patch extracted: depth 176, height 64, width 0
# Patch extracted: depth 176, height 64, width 16
# Patch extracted: depth 176, height 64, width 32
# Patch extracted: depth 176, height 80, width 0
# Patch extracted: depth 176, height 80, width 16
# Patch extracted: depth 176, height 80, width 32
# Patch extracted: depth 176, height 96, width 0
# Patch extracted: depth 176, height 96, width 16
# Patch extracted: depth 176, height 96, width 32
# Patch extracted: depth 176, height 112, width 0
# Patch extracted: depth 176, height 112, width 16
# Patch extracted: depth 176, height 112, width 32
# Patch extracted: depth 176, height 128, width 0
# Patch extracted: depth 176, height 128, width 16
# Patch extracted: depth 176, height 128, width 32
# Patch extracted: depth 176, height 144, width 0
# Patch extracted: depth 176, height 144, width 16
# Patch extracted: depth 176, height 144, width 32
# Patch extracted: depth 176, height 160, width 0
# Patch extracted: depth 176, height 160, width 16
# Patch extracted: depth 176, height 160, width 32
# Patch extracted: depth 176, height 176, width 0
# Patch extracted: depth 176, height 176, width 16
# Patch extracted: depth 176, height 176, width 32
# Total patches extracted: 432
#  - Number of image patches extracted: 432
#  - Number of mask patches extracted: 432
# Number of image patches: 3024

# %%
print(len(dataset.patches_img))
print(len(dataset.patches_mask))
# Out:
# 3024
# 3024

# %%
# Validation split from dataset (20% validation, 80% training)
train_dataset, val_dataset = train_test_split(dataset, test_size=0.2, random_state=42)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# %%
for inputs, labels in train_loader:
    # Print shapes of inputs and labels
    print(f"Input shape: {inputs.shape}")
    print(f"Label shape: {labels.shape}")
    break
# Out:
# Input shape: torch.Size([16, 3, 64, 64, 16])
# Label shape: torch.Size([16, 64, 64, 16])

# %%
# Define the 3D U-Net model with transition layers
class UNet3D(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(UNet3D, self).__init__()

        # Encoder with transition layers
        self.encoder1 = self.contract_block(in_channels, 32, kernel_size=3, padding=1)
        self.trans1 = nn.MaxPool3d(2)  # Downsampling layer
        self.encoder2 = self.contract_block(32, 64, kernel_size=3, padding=1)
        self.trans2 = nn.MaxPool3d(2)  # Downsampling layer
        self.encoder3 = self.contract_block(64, 128, kernel_size=3, padding=1)
        self.trans3 = nn.MaxPool3d(2)  # Downsampling layer

        # Bottleneck
        self.bottleneck = nn.Sequential(
            nn.Conv3d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv3d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )

        # Decoder with transition layers
        self.uptrans3 = nn.ConvTranspose3d(256, 128, kernel_size=2, stride=2)  # Upsampling layer
        self.decoder3 = self.expand_block(256, 128, kernel_size=3, padding=1)
        self.uptrans2 = nn.ConvTranspose3d(128, 64, kernel_size=2, stride=2)   # Upsampling layer
        self.decoder2 = self.expand_block(128, 64, kernel_size=3, padding=1)
        self.uptrans1 = nn.ConvTranspose3d(64, 32, kernel_size=2, stride=2)    # Upsampling layer
        self.decoder1 = self.expand_block(64, 32, kernel_size=3, padding=1)

        # Output layer - out_channels = number of classes (no softmax here)
        self.out = nn.Conv3d(32, out_channels, kernel_size=1)

    def contract_block(self, in_channels, out_channels, kernel_size=3, padding=1):
        return nn.Sequential(
            nn.Conv3d(in_channels, out_channels, kernel_size=kernel_size, padding=padding),
            nn.ReLU(inplace=True),
            nn.Conv3d(out_channels, out_channels, kernel_size=kernel_size, padding=padding),
            nn.ReLU(inplace=True)
        )

    def expand_block(self, in_channels, out_channels, kernel_size=3, padding=1):
        return nn.Sequential(
            nn.Conv3d(in_channels, out_channels, kernel_size=kernel_size, padding=padding),
            nn.ReLU(inplace=True),
            nn.Conv3d(out_channels, out_channels, kernel_size=kernel_size, padding=padding),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        # Encoder
        enc1 = self.encoder1(x)
        enc2 = self.encoder2(self.trans1(enc1))
        enc3 = self.encoder3(self.trans2(enc2))

        # Bottleneck
        bottleneck = self.bottleneck(self.trans3(enc3))

        # Decoder
        dec3 = self.uptrans3(bottleneck)
        dec3 = torch.cat((dec3, enc3), dim=1)  # Skip connection
        dec3 = self.decoder3(dec3)
        dec2 = self.uptrans2(dec3)
        dec2 = torch.cat((dec2, enc2), dim=1)  # Skip connection
        dec2 = self.decoder2(dec2)
        dec1 = self.uptrans1(dec2)
        dec1 = torch.cat((dec1, enc1), dim=1)  # Skip connection
        dec1 = self.decoder1(dec1)

        # Output layer with raw logits (no activation)
        out = self.out(dec1)
        return out

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
# Training settings
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Initialize the model
model = UNet3D(in_channels=3, out_channels=8)  # 8 labels to segment (excluding background)
model.to(device)
# Out:
# UNet3D(
#   (encoder1): Sequential(
#     (0): Conv3d(3, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (trans1): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (encoder2): Sequential(
#     (0): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (trans2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (encoder3): Sequential(
#     (0): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (trans3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (bottleneck): Sequential(
#     (0): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (uptrans3): ConvTranspose3d(256, 128, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#   (decoder3): Sequential(
#     (0): Conv3d(256, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (uptrans2): ConvTranspose3d(128, 64, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#   (decoder2): Sequential(
#     (0): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (uptrans1): ConvTranspose3d(64, 32, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#   (decoder1): Sequential(
#     (0): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (out): Conv3d(32, 8, kernel_size=(1, 1, 1), stride=(1, 1, 1))
# )

# %%
# Define loss function and optimizer

optimizer = torch.optim.Adam(model.parameters(), lr=0.00000001, weight_decay=1e-5)
criterion = torch.nn.CrossEntropyLoss()

# %%
for name, param in model.named_parameters():
    if torch.isnan(param).any():
        print(f"NaN detected in weights: {name}")

# %%
os.environ['TORCH_USE_CUDA_DSA'] = '1'

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
epochs = 1000

# %%
# Training and validation loop
scaler = GradScaler()  # For mixed precision training

# %%
def weights_init(m):
    if isinstance(m, nn.Conv3d):
        nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)

# %%
model.apply(weights_init)
# Out:
# UNet3D(
#   (encoder1): Sequential(
#     (0): Conv3d(3, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (trans1): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (encoder2): Sequential(
#     (0): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (trans2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (encoder3): Sequential(
#     (0): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (trans3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (bottleneck): Sequential(
#     (0): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (uptrans3): ConvTranspose3d(256, 128, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#   (decoder3): Sequential(
#     (0): Conv3d(256, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (uptrans2): ConvTranspose3d(128, 64, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#   (decoder2): Sequential(
#     (0): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (uptrans1): ConvTranspose3d(64, 32, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#   (decoder1): Sequential(
#     (0): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (out): Conv3d(32, 8, kernel_size=(1, 1, 1), stride=(1, 1, 1))
# )

# %%
def calculate_accuracy(preds, labels):
    # Apply softmax to get class probabilities
    preds = torch.argmax(preds, dim=1)  # Get the class with the highest score along the channel dimension (class dimension)
    
    # Ensure labels have the correct shape (if labels are one-hot encoded, convert to class indices)
    if labels.dim() == 4:  # For one-hot encoded labels
        labels = torch.argmax(labels, dim=1)  # Convert one-hot encoded labels to class indices
    
    # Ensure preds and labels have the same shape
    if preds.shape != labels.shape:
        raise RuntimeError(f"Shape mismatch: preds {preds.shape}, labels {labels.shape}")
    
    # Calculate the number of correct predictions
    correct = (preds == labels).float().sum()  # Count the correct pixel predictions
    accuracy = correct / labels.numel()  # Normalize by the total number of pixels
    
    return accuracy

# %%
# Define patience for early stopping and the learning rate scheduler
patience = 3  # Number of epochs to wait before stopping if no improvement
best_val_loss = np.inf  # Track the best validation loss
early_stop_counter = 0  # Counter for early stopping
# Define the scheduler
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=2, verbose=True)

for epoch in range(epochs):
    print(f"Epoch {epoch+1}/{epochs}")

    # Training phase
    model.train()
    train_loss = 0.0
    train_accuracy = 0.0

    for i, (images, masks) in enumerate(train_loader):
        images = images.type(torch.float32).to(device)  # Ensure float32
        masks = masks.to(device)
        images = (images - images.min()) / (images.max() - images.min())

        if torch.isnan(images).any():
            print("NaN detected in input images.")
        if torch.isnan(masks).any():
            print("NaN detected in input masks.")

        # Forward pass
        with autocast(device_type='cuda'):
            outputs = model(images)
            outputs = outputs[:, 0, :, :, :]
            loss = criterion(outputs, masks)

        # Backward pass and optimization
        optimizer.zero_grad()
        scaler.scale(loss).backward()

        scaler.step(optimizer)
        scaler.update()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        train_loss += loss.item()
        train_accuracy += calculate_accuracy(outputs, masks).item()

    avg_train_loss = train_loss / len(train_loader)
    avg_train_acc = train_accuracy / len(train_loader)
    print(f"Training Loss: {avg_train_loss:.4f}, Training Accuracy: {avg_train_acc:.4f}")

    # Validation phase
    model.eval()
    val_loss = 0.0
    val_accuracy = 0.0

    with torch.no_grad():
        for i, (images, masks) in enumerate(val_loader):
            images = images.type(torch.float32).to(device)  # Ensure float32
            masks = masks.to(device)
            images = (images - images.min()) / (images.max() - images.min())

            if torch.isnan(images).any():
                print("NaN detected in input images.")
            if torch.isnan(masks).any():
                print("NaN detected in input masks.")

            # Forward pass
            outputs = model(images)
            outputs = outputs[:, 0, :, :, :]
            loss = criterion(outputs, masks)

            val_loss += loss.item()
            val_accuracy += calculate_accuracy(outputs, masks).item()

    avg_val_loss = val_loss / len(val_loader)
    avg_val_acc = val_accuracy / len(val_loader)
    print(f"Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {avg_val_acc:.4f}")

    # Step the scheduler based on validation loss
    scheduler.step(avg_val_loss)

    # Early Stopping
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        early_stop_counter = 0  # Reset counter if validation loss improves
        # Optionally save the best model
        torch.save(model.state_dict(), 'best_model.pth')
        print(f"New best validation loss: {best_val_loss:.4f}, saving model.")
    else:
        early_stop_counter += 1
        print(f"No improvement in validation loss. Early stop counter: {early_stop_counter}/{patience}")

    if early_stop_counter >= patience:
        print("Early stopping triggered. Stopping training.")
        break
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/1000
# Training Loss: 267.7361, Training Accuracy: 0.5151
# Validation Loss: 242.9583, Validation Accuracy: 0.5349
# New best validation loss: 242.9583, saving model.
# Epoch 2/1000
# Training Loss: 267.8791, Training Accuracy: 0.5154
# Validation Loss: 242.9555, Validation Accuracy: 0.5356
# New best validation loss: 242.9555, saving model.
# Epoch 3/1000
# Training Loss: 268.1428, Training Accuracy: 0.5150
# Validation Loss: 242.9528, Validation Accuracy: 0.5363
# New best validation loss: 242.9528, saving model.
# Epoch 4/1000
# Training Loss: 268.8160, Training Accuracy: 0.5157
# Validation Loss: 242.9500, Validation Accuracy: 0.5368
# New best validation loss: 242.9500, saving model.
# Epoch 5/1000
# Training Loss: 267.3186, Training Accuracy: 0.5176
# Validation Loss: 242.9472, Validation Accuracy: 0.5375
# New best validation loss: 242.9472, saving model.
# Epoch 6/1000
# Training Loss: 268.5024, Training Accuracy: 0.5187
# Validation Loss: 242.9445, Validation Accuracy: 0.5380
# New best validation loss: 242.9445, saving model.
# Epoch 7/1000
# Training Loss: 268.5621, Training Accuracy: 0.5170
# Validation Loss: 242.9417, Validation Accuracy: 0.5386
# New best validation loss: 242.9417, saving model.
# Epoch 8/1000
# Training Loss: 266.7946, Training Accuracy: 0.5199
# Validation Loss: 242.9390, Validation Accuracy: 0.5392
# New best validation loss: 242.9390, saving model.
# Epoch 9/1000
# Training Loss: 268.3543, Training Accuracy: 0.5200
# Validation Loss: 242.9363, Validation Accuracy: 0.5398
# New best validation loss: 242.9363, saving model.
# Epoch 10/1000
# Training Loss: 269.9106, Training Accuracy: 0.5196
# Validation Loss: 242.9335, Validation Accuracy: 0.5403
# New best validation loss: 242.9335, saving model.
# Epoch 11/1000
# Training Loss: 266.6147, Training Accuracy: 0.5220
# Validation Loss: 242.9308, Validation Accuracy: 0.5408
# New best validation loss: 242.9308, saving model.
# Epoch 12/1000
# Training Loss: 268.6873, Training Accuracy: 0.5215
# Validation Loss: 242.9281, Validation Accuracy: 0.5413
# New best validation loss: 242.9281, saving model.
# Epoch 13/1000
# Training Loss: 267.3163, Training Accuracy: 0.5230
# Validation Loss: 242.9254, Validation Accuracy: 0.5418
# New best validation loss: 242.9254, saving model.
# Epoch 14/1000
# Training Loss: 268.3543, Training Accuracy: 0.5220
# Validation Loss: 242.9227, Validation Accuracy: 0.5423
# New best validation loss: 242.9227, saving model.
# Epoch 15/1000
# Training Loss: 267.2566, Training Accuracy: 0.5231
# Validation Loss: 242.9200, Validation Accuracy: 0.5427
# New best validation loss: 242.9200, saving model.
# Epoch 16/1000
# Training Loss: 267.1146, Training Accuracy: 0.5240
# Validation Loss: 242.9173, Validation Accuracy: 0.5432
# New best validation loss: 242.9173, saving model.
# Epoch 17/1000
# Training Loss: 268.2432, Training Accuracy: 0.5227
# Validation Loss: 242.9146, Validation Accuracy: 0.5437
# New best validation loss: 242.9146, saving model.
# Epoch 18/1000
# Training Loss: 268.3616, Training Accuracy: 0.5228
# Validation Loss: 242.9119, Validation Accuracy: 0.5441
# New best validation loss: 242.9119, saving model.
# Epoch 19/1000
# Training Loss: 268.7284, Training Accuracy: 0.5237
# Validation Loss: 242.9093, Validation Accuracy: 0.5445
# New best validation loss: 242.9093, saving model.
# Epoch 20/1000
# Training Loss: 268.8041, Training Accuracy: 0.5242
# Validation Loss: 242.9066, Validation Accuracy: 0.5449
# New best validation loss: 242.9066, saving model.
# Epoch 21/1000
# Training Loss: 269.2854, Training Accuracy: 0.5240
# Validation Loss: 242.9040, Validation Accuracy: 0.5454
# New best validation loss: 242.9040, saving model.
# Epoch 22/1000
# Training Loss: 267.9687, Training Accuracy: 0.5260
# Validation Loss: 242.9013, Validation Accuracy: 0.5458
# New best validation loss: 242.9013, saving model.
# Epoch 23/1000
# Training Loss: 267.3295, Training Accuracy: 0.5255
# Validation Loss: 242.8987, Validation Accuracy: 0.5462
# New best validation loss: 242.8987, saving model.
# Epoch 24/1000
# Training Loss: 267.3780, Training Accuracy: 0.5262
# Validation Loss: 242.8961, Validation Accuracy: 0.5466
# New best validation loss: 242.8961, saving model.
# Epoch 25/1000
# Training Loss: 268.7277, Training Accuracy: 0.5252
# Validation Loss: 242.8934, Validation Accuracy: 0.5470
# New best validation loss: 242.8934, saving model.
# Epoch 26/1000
# Training Loss: 267.5460, Training Accuracy: 0.5285
# Validation Loss: 242.8909, Validation Accuracy: 0.5474
# New best validation loss: 242.8909, saving model.
# Epoch 27/1000
# Training Loss: 268.5955, Training Accuracy: 0.5282
# Validation Loss: 242.8883, Validation Accuracy: 0.5477
# New best validation loss: 242.8883, saving model.
# Epoch 28/1000
# Training Loss: 269.4693, Training Accuracy: 0.5272
# Validation Loss: 242.8857, Validation Accuracy: 0.5481
# New best validation loss: 242.8857, saving model.
# Epoch 29/1000
# Training Loss: 268.4258, Training Accuracy: 0.5276
# Validation Loss: 242.8831, Validation Accuracy: 0.5484
# New best validation loss: 242.8831, saving model.
# Epoch 30/1000
# Training Loss: 266.6654, Training Accuracy: 0.5295
# Validation Loss: 242.8805, Validation Accuracy: 0.5488
# New best validation loss: 242.8805, saving model.
# Epoch 31/1000
# Training Loss: 267.9106, Training Accuracy: 0.5288
# Validation Loss: 242.8779, Validation Accuracy: 0.5490
# New best validation loss: 242.8779, saving model.
# Epoch 32/1000
# Training Loss: 267.5309, Training Accuracy: 0.5276
# Validation Loss: 242.8753, Validation Accuracy: 0.5493
# New best validation loss: 242.8753, saving model.
# Epoch 33/1000
# Training Loss: 268.6559, Training Accuracy: 0.5289
# Validation Loss: 242.8727, Validation Accuracy: 0.5495
# New best validation loss: 242.8727, saving model.
# Epoch 34/1000
# Training Loss: 268.1362, Training Accuracy: 0.5305
# Validation Loss: 242.8702, Validation Accuracy: 0.5498
# New best validation loss: 242.8702, saving model.
# Epoch 35/1000
# Training Loss: 267.8628, Training Accuracy: 0.5291
# Validation Loss: 242.8676, Validation Accuracy: 0.5501
# New best validation loss: 242.8676, saving model.
# Epoch 36/1000
# Training Loss: 267.6710, Training Accuracy: 0.5297
# Validation Loss: 242.8650, Validation Accuracy: 0.5503
# New best validation loss: 242.8650, saving model.
# Epoch 37/1000
# Training Loss: 266.7086, Training Accuracy: 0.5317
# Validation Loss: 242.8625, Validation Accuracy: 0.5505
# New best validation loss: 242.8625, saving model.
# Epoch 38/1000
# Training Loss: 266.8348, Training Accuracy: 0.5318
# Validation Loss: 242.8599, Validation Accuracy: 0.5508
# New best validation loss: 242.8599, saving model.
# Epoch 39/1000
# Training Loss: 268.7745, Training Accuracy: 0.5302
# Validation Loss: 242.8574, Validation Accuracy: 0.5510
# New best validation loss: 242.8574, saving model.
# Epoch 40/1000
# Training Loss: 266.8760, Training Accuracy: 0.5311
# Validation Loss: 242.8548, Validation Accuracy: 0.5512
# New best validation loss: 242.8548, saving model.
# Epoch 41/1000
# Training Loss: 267.4748, Training Accuracy: 0.5311
# Validation Loss: 242.8522, Validation Accuracy: 0.5515
# New best validation loss: 242.8522, saving model.
# Epoch 42/1000
# Training Loss: 267.3684, Training Accuracy: 0.5321
# Validation Loss: 242.8497, Validation Accuracy: 0.5517
# New best validation loss: 242.8497, saving model.
# Epoch 43/1000
# Training Loss: 268.1316, Training Accuracy: 0.5316
# Validation Loss: 242.8471, Validation Accuracy: 0.5519
# New best validation loss: 242.8471, saving model.
# Epoch 44/1000
# Training Loss: 267.5299, Training Accuracy: 0.5323
# Validation Loss: 242.8446, Validation Accuracy: 0.5520
# New best validation loss: 242.8446, saving model.
# Epoch 45/1000
# Training Loss: 268.5198, Training Accuracy: 0.5315
# Validation Loss: 242.8420, Validation Accuracy: 0.5522
# New best validation loss: 242.8420, saving model.
# Epoch 46/1000
# Training Loss: 268.2179, Training Accuracy: 0.5318
# Validation Loss: 242.8395, Validation Accuracy: 0.5523
# New best validation loss: 242.8395, saving model.
# Epoch 47/1000
# Training Loss: 268.2779, Training Accuracy: 0.5330
# Validation Loss: 242.8369, Validation Accuracy: 0.5525
# New best validation loss: 242.8369, saving model.
# Epoch 48/1000
# Training Loss: 267.6105, Training Accuracy: 0.5336
# Validation Loss: 242.8344, Validation Accuracy: 0.5527
# New best validation loss: 242.8344, saving model.
# Epoch 49/1000
# Training Loss: 268.7765, Training Accuracy: 0.5328
# Validation Loss: 242.8319, Validation Accuracy: 0.5529
# New best validation loss: 242.8319, saving model.
# Epoch 50/1000
# Training Loss: 268.3518, Training Accuracy: 0.5307
# Validation Loss: 242.8293, Validation Accuracy: 0.5530
# New best validation loss: 242.8293, saving model.
# Epoch 51/1000
# Training Loss: 268.6544, Training Accuracy: 0.5319
# Validation Loss: 242.8268, Validation Accuracy: 0.5531
# New best validation loss: 242.8268, saving model.
# Epoch 52/1000
# Training Loss: 268.3163, Training Accuracy: 0.5334
# Validation Loss: 242.8242, Validation Accuracy: 0.5533
# New best validation loss: 242.8242, saving model.
# Epoch 53/1000
# Training Loss: 267.4135, Training Accuracy: 0.5333
# Validation Loss: 242.8217, Validation Accuracy: 0.5534
# New best validation loss: 242.8217, saving model.
# Epoch 54/1000
# Training Loss: 266.8494, Training Accuracy: 0.5341
# Validation Loss: 242.8192, Validation Accuracy: 0.5536
# New best validation loss: 242.8192, saving model.
# Epoch 55/1000
# Training Loss: 269.1023, Training Accuracy: 0.5333
# Validation Loss: 242.8167, Validation Accuracy: 0.5538
# New best validation loss: 242.8167, saving model.
# Epoch 56/1000
# Training Loss: 268.1266, Training Accuracy: 0.5348
# Validation Loss: 242.8142, Validation Accuracy: 0.5539
# New best validation loss: 242.8142, saving model.
# Epoch 57/1000
# Training Loss: 268.0292, Training Accuracy: 0.5340
# Validation Loss: 242.8116, Validation Accuracy: 0.5541
# New best validation loss: 242.8116, saving model.
# Epoch 58/1000
# Training Loss: 268.7568, Training Accuracy: 0.5332
# Validation Loss: 242.8091, Validation Accuracy: 0.5542
# New best validation loss: 242.8091, saving model.
# Epoch 59/1000
# Training Loss: 270.0442, Training Accuracy: 0.5326
# Validation Loss: 242.8066, Validation Accuracy: 0.5543
# New best validation loss: 242.8066, saving model.
# Epoch 60/1000
# Training Loss: 268.0202, Training Accuracy: 0.5356
# Validation Loss: 242.8041, Validation Accuracy: 0.5545
# New best validation loss: 242.8041, saving model.
# Epoch 61/1000
# Training Loss: 268.2058, Training Accuracy: 0.5351
# Validation Loss: 242.8016, Validation Accuracy: 0.5546
# New best validation loss: 242.8016, saving model.
# Epoch 62/1000
# Training Loss: 268.1479, Training Accuracy: 0.5341
# Validation Loss: 242.7991, Validation Accuracy: 0.5547
# New best validation loss: 242.7991, saving model.
# Epoch 63/1000
# Training Loss: 268.2894, Training Accuracy: 0.5347
# Validation Loss: 242.7965, Validation Accuracy: 0.5549
# New best validation loss: 242.7965, saving model.
# Epoch 64/1000
# Training Loss: 267.3455, Training Accuracy: 0.5365
# Validation Loss: 242.7940, Validation Accuracy: 0.5550
# New best validation loss: 242.7940, saving model.
# Epoch 65/1000
# Training Loss: 266.9925, Training Accuracy: 0.5357
# Validation Loss: 242.7915, Validation Accuracy: 0.5551
# New best validation loss: 242.7915, saving model.
# Epoch 66/1000
# Training Loss: 266.9561, Training Accuracy: 0.5371
# Validation Loss: 242.7890, Validation Accuracy: 0.5553
# New best validation loss: 242.7890, saving model.
# Epoch 67/1000
# Training Loss: 267.7874, Training Accuracy: 0.5365
# Validation Loss: 242.7865, Validation Accuracy: 0.5554
# New best validation loss: 242.7865, saving model.
# Epoch 68/1000
# Training Loss: 266.6056, Training Accuracy: 0.5368
# Validation Loss: 242.7840, Validation Accuracy: 0.5556
# New best validation loss: 242.7840, saving model.
# Epoch 69/1000
# Training Loss: 268.5209, Training Accuracy: 0.5367
# Validation Loss: 242.7815, Validation Accuracy: 0.5557
# New best validation loss: 242.7815, saving model.
# Epoch 70/1000
# Training Loss: 267.1807, Training Accuracy: 0.5364
# Validation Loss: 242.7790, Validation Accuracy: 0.5558
# New best validation loss: 242.7790, saving model.
# Epoch 71/1000
# Training Loss: 266.9355, Training Accuracy: 0.5370
# Validation Loss: 242.7765, Validation Accuracy: 0.5559
# New best validation loss: 242.7765, saving model.
# Epoch 72/1000
# Training Loss: 269.6006, Training Accuracy: 0.5354
# Validation Loss: 242.7740, Validation Accuracy: 0.5560
# New best validation loss: 242.7740, saving model.
# Epoch 73/1000
# Training Loss: 267.4805, Training Accuracy: 0.5366
# Validation Loss: 242.7715, Validation Accuracy: 0.5561
# New best validation loss: 242.7715, saving model.
# Epoch 74/1000
# Training Loss: 267.9938, Training Accuracy: 0.5361
# Validation Loss: 242.7690, Validation Accuracy: 0.5561
# New best validation loss: 242.7690, saving model.
# Epoch 75/1000
# Training Loss: 267.8754, Training Accuracy: 0.5369
# Validation Loss: 242.7665, Validation Accuracy: 0.5562
# New best validation loss: 242.7665, saving model.
# Epoch 76/1000
# Training Loss: 268.3417, Training Accuracy: 0.5357
# Validation Loss: 242.7639, Validation Accuracy: 0.5562
# New best validation loss: 242.7639, saving model.
# Epoch 77/1000
# Training Loss: 266.5829, Training Accuracy: 0.5370
# Validation Loss: 242.7614, Validation Accuracy: 0.5563
# New best validation loss: 242.7614, saving model.
# Epoch 78/1000
# Training Loss: 267.0659, Training Accuracy: 0.5369
# Validation Loss: 242.7589, Validation Accuracy: 0.5563
# New best validation loss: 242.7589, saving model.
# Epoch 79/1000
# Training Loss: 267.3773, Training Accuracy: 0.5374
# Validation Loss: 242.7564, Validation Accuracy: 0.5563
# New best validation loss: 242.7564, saving model.
# Epoch 80/1000
# Training Loss: 268.5028, Training Accuracy: 0.5363
# Validation Loss: 242.7539, Validation Accuracy: 0.5564
# New best validation loss: 242.7539, saving model.
# Epoch 81/1000
# Training Loss: 267.1983, Training Accuracy: 0.5362
# Validation Loss: 242.7514, Validation Accuracy: 0.5564
# New best validation loss: 242.7514, saving model.
# Epoch 82/1000
# Training Loss: 268.4543, Training Accuracy: 0.5355
# Validation Loss: 242.7489, Validation Accuracy: 0.5564
# New best validation loss: 242.7489, saving model.
# Epoch 83/1000
# Training Loss: 267.6429, Training Accuracy: 0.5369
# Validation Loss: 242.7464, Validation Accuracy: 0.5564
# New best validation loss: 242.7464, saving model.
# Epoch 84/1000
# Training Loss: 267.9637, Training Accuracy: 0.5366
# Validation Loss: 242.7438, Validation Accuracy: 0.5565
# New best validation loss: 242.7438, saving model.
# Epoch 85/1000
# Training Loss: 267.2488, Training Accuracy: 0.5377
# Validation Loss: 242.7413, Validation Accuracy: 0.5565
# New best validation loss: 242.7413, saving model.
# Epoch 86/1000
# Training Loss: 267.8794, Training Accuracy: 0.5364
# Validation Loss: 242.7389, Validation Accuracy: 0.5565
# New best validation loss: 242.7389, saving model.
# Epoch 87/1000
# Training Loss: 267.8894, Training Accuracy: 0.5370
# Validation Loss: 242.7364, Validation Accuracy: 0.5565
# New best validation loss: 242.7364, saving model.
# Epoch 88/1000
# Training Loss: 267.3326, Training Accuracy: 0.5377
# Validation Loss: 242.7339, Validation Accuracy: 0.5564
# New best validation loss: 242.7339, saving model.
# Epoch 89/1000
# Training Loss: 266.8165, Training Accuracy: 0.5379
# Validation Loss: 242.7314, Validation Accuracy: 0.5564
# New best validation loss: 242.7314, saving model.
# Epoch 90/1000
# Training Loss: 270.2294, Training Accuracy: 0.5361
# Validation Loss: 242.7289, Validation Accuracy: 0.5564
# New best validation loss: 242.7289, saving model.
# Epoch 91/1000
# Training Loss: 267.9930, Training Accuracy: 0.5349
# Validation Loss: 242.7264, Validation Accuracy: 0.5564
# New best validation loss: 242.7264, saving model.
# Epoch 92/1000
# Training Loss: 269.1361, Training Accuracy: 0.5351
# Validation Loss: 242.7239, Validation Accuracy: 0.5564
# New best validation loss: 242.7239, saving model.
# Epoch 93/1000
# Training Loss: 267.8408, Training Accuracy: 0.5357
# Validation Loss: 242.7214, Validation Accuracy: 0.5564
# New best validation loss: 242.7214, saving model.
# Epoch 94/1000
# Training Loss: 268.1828, Training Accuracy: 0.5369
# Validation Loss: 242.7189, Validation Accuracy: 0.5564
# New best validation loss: 242.7189, saving model.
# Epoch 95/1000
# Training Loss: 267.5500, Training Accuracy: 0.5361
# Validation Loss: 242.7165, Validation Accuracy: 0.5564
# New best validation loss: 242.7165, saving model.
# Epoch 96/1000
# Training Loss: 266.6151, Training Accuracy: 0.5377
# Validation Loss: 242.7140, Validation Accuracy: 0.5564
# New best validation loss: 242.7140, saving model.
# Epoch 97/1000
# Training Loss: 266.9588, Training Accuracy: 0.5373
# Validation Loss: 242.7115, Validation Accuracy: 0.5563
# New best validation loss: 242.7115, saving model.
# Epoch 98/1000
# Training Loss: 267.9688, Training Accuracy: 0.5361
# Validation Loss: 242.7091, Validation Accuracy: 0.5563
# New best validation loss: 242.7091, saving model.
# Epoch 99/1000
# Training Loss: 267.3072, Training Accuracy: 0.5358
# Validation Loss: 242.7066, Validation Accuracy: 0.5563
# New best validation loss: 242.7066, saving model.
# Epoch 100/1000
# Training Loss: 267.6047, Training Accuracy: 0.5364
# Validation Loss: 242.7042, Validation Accuracy: 0.5562
# New best validation loss: 242.7042, saving model.
# Epoch 101/1000
# Training Loss: 266.9248, Training Accuracy: 0.5374
# Validation Loss: 242.7017, Validation Accuracy: 0.5562
# New best validation loss: 242.7017, saving model.
# Epoch 102/1000
# Training Loss: 268.3968, Training Accuracy: 0.5354
# Validation Loss: 242.6993, Validation Accuracy: 0.5562
# New best validation loss: 242.6993, saving model.
# Epoch 103/1000
# Training Loss: 267.6047, Training Accuracy: 0.5367
# Validation Loss: 242.6969, Validation Accuracy: 0.5561
# New best validation loss: 242.6969, saving model.
# Epoch 104/1000
# Training Loss: 267.4840, Training Accuracy: 0.5354
# Validation Loss: 242.6945, Validation Accuracy: 0.5561
# New best validation loss: 242.6945, saving model.
# Epoch 105/1000
# Training Loss: 267.0407, Training Accuracy: 0.5354
# Validation Loss: 242.6920, Validation Accuracy: 0.5561
# New best validation loss: 242.6920, saving model.
# Epoch 106/1000
# Training Loss: 266.6325, Training Accuracy: 0.5369
# Validation Loss: 242.6896, Validation Accuracy: 0.5560
# New best validation loss: 242.6896, saving model.
# Epoch 107/1000
# Training Loss: 267.5698, Training Accuracy: 0.5353
# Validation Loss: 242.6872, Validation Accuracy: 0.5560
# New best validation loss: 242.6872, saving model.
# Epoch 108/1000
# Training Loss: 267.8372, Training Accuracy: 0.5362
# Validation Loss: 242.6847, Validation Accuracy: 0.5559
# New best validation loss: 242.6847, saving model.
# Epoch 109/1000
# Training Loss: 267.2611, Training Accuracy: 0.5370
# Validation Loss: 242.6823, Validation Accuracy: 0.5559
# New best validation loss: 242.6823, saving model.
# Epoch 110/1000
# Training Loss: 268.5472, Training Accuracy: 0.5351
# Validation Loss: 242.6800, Validation Accuracy: 0.5558
# New best validation loss: 242.6800, saving model.
# Epoch 111/1000
# Training Loss: 267.4817, Training Accuracy: 0.5362
# Validation Loss: 242.6776, Validation Accuracy: 0.5558
# New best validation loss: 242.6776, saving model.
# Epoch 112/1000
# Training Loss: 266.6084, Training Accuracy: 0.5372
# Validation Loss: 242.6752, Validation Accuracy: 0.5557
# New best validation loss: 242.6752, saving model.
# Epoch 113/1000
# Training Loss: 267.0557, Training Accuracy: 0.5366
# Validation Loss: 242.6728, Validation Accuracy: 0.5556
# New best validation loss: 242.6728, saving model.
# Epoch 114/1000
# Training Loss: 268.0808, Training Accuracy: 0.5355
# Validation Loss: 242.6704, Validation Accuracy: 0.5556
# New best validation loss: 242.6704, saving model.
# Epoch 115/1000
# Training Loss: 271.2945, Training Accuracy: 0.5355
# Validation Loss: 242.6681, Validation Accuracy: 0.5555
# New best validation loss: 242.6681, saving model.
# Epoch 116/1000
# Training Loss: 267.0371, Training Accuracy: 0.5358
# Validation Loss: 242.6657, Validation Accuracy: 0.5555
# New best validation loss: 242.6657, saving model.
# Epoch 117/1000
# Training Loss: 267.6171, Training Accuracy: 0.5355
# Validation Loss: 242.6633, Validation Accuracy: 0.5554
# New best validation loss: 242.6633, saving model.
# Epoch 118/1000
# Training Loss: 267.7471, Training Accuracy: 0.5359
# Validation Loss: 242.6610, Validation Accuracy: 0.5554
# New best validation loss: 242.6610, saving model.
# Epoch 119/1000
# Training Loss: 266.7202, Training Accuracy: 0.5372
# Validation Loss: 242.6586, Validation Accuracy: 0.5553
# New best validation loss: 242.6586, saving model.
# Epoch 120/1000
# Training Loss: 266.7165, Training Accuracy: 0.5374
# Validation Loss: 242.6563, Validation Accuracy: 0.5552
# New best validation loss: 242.6563, saving model.
# Epoch 121/1000
# Training Loss: 266.6173, Training Accuracy: 0.5349
# Validation Loss: 242.6539, Validation Accuracy: 0.5551
# New best validation loss: 242.6539, saving model.
# Epoch 122/1000
# Training Loss: 266.8201, Training Accuracy: 0.5360
# Validation Loss: 242.6516, Validation Accuracy: 0.5551
# New best validation loss: 242.6516, saving model.
# Epoch 123/1000
# Training Loss: 266.8593, Training Accuracy: 0.5364
# Validation Loss: 242.6492, Validation Accuracy: 0.5550
# New best validation loss: 242.6492, saving model.
# Epoch 124/1000
# Training Loss: 268.7938, Training Accuracy: 0.5346
# Validation Loss: 242.6469, Validation Accuracy: 0.5549
# New best validation loss: 242.6469, saving model.
# Epoch 125/1000
# Training Loss: 269.8029, Training Accuracy: 0.5339
# Validation Loss: 242.6445, Validation Accuracy: 0.5548
# New best validation loss: 242.6445, saving model.
# Epoch 126/1000
# Training Loss: 268.3845, Training Accuracy: 0.5333
# Validation Loss: 242.6422, Validation Accuracy: 0.5548
# New best validation loss: 242.6422, saving model.
# Epoch 127/1000
# Training Loss: 267.7131, Training Accuracy: 0.5342
# Validation Loss: 242.6398, Validation Accuracy: 0.5547
# New best validation loss: 242.6398, saving model.
# Epoch 128/1000
# Training Loss: 266.9865, Training Accuracy: 0.5353
# Validation Loss: 242.6375, Validation Accuracy: 0.5546
# New best validation loss: 242.6375, saving model.
# Epoch 129/1000
# Training Loss: 267.8135, Training Accuracy: 0.5349
# Validation Loss: 242.6352, Validation Accuracy: 0.5546
# New best validation loss: 242.6352, saving model.
# Epoch 130/1000
# Training Loss: 268.5915, Training Accuracy: 0.5342
# Validation Loss: 242.6329, Validation Accuracy: 0.5545
# New best validation loss: 242.6329, saving model.
# Epoch 131/1000
# Training Loss: 268.1062, Training Accuracy: 0.5357
# Validation Loss: 242.6305, Validation Accuracy: 0.5544
# New best validation loss: 242.6305, saving model.
# Epoch 132/1000
# Training Loss: 267.8216, Training Accuracy: 0.5353
# Validation Loss: 242.6283, Validation Accuracy: 0.5543
# New best validation loss: 242.6283, saving model.
# Epoch 133/1000
# Training Loss: 267.9899, Training Accuracy: 0.5349
# Validation Loss: 242.6259, Validation Accuracy: 0.5543
# New best validation loss: 242.6259, saving model.
# Epoch 134/1000
# Training Loss: 268.2564, Training Accuracy: 0.5344
# Validation Loss: 242.6236, Validation Accuracy: 0.5542
# New best validation loss: 242.6236, saving model.
# Epoch 135/1000
# Training Loss: 267.6400, Training Accuracy: 0.5340
# Validation Loss: 242.6213, Validation Accuracy: 0.5542
# New best validation loss: 242.6213, saving model.
# Epoch 136/1000
# Training Loss: 269.2088, Training Accuracy: 0.5340
# Validation Loss: 242.6190, Validation Accuracy: 0.5541
# New best validation loss: 242.6190, saving model.
# Epoch 137/1000
# Training Loss: 269.1767, Training Accuracy: 0.5329
# Validation Loss: 242.6167, Validation Accuracy: 0.5541
# New best validation loss: 242.6167, saving model.
# Epoch 138/1000
# Training Loss: 266.5506, Training Accuracy: 0.5354
# Validation Loss: 242.6144, Validation Accuracy: 0.5540
# New best validation loss: 242.6144, saving model.
# Epoch 139/1000
# Training Loss: 266.7164, Training Accuracy: 0.5345
# Validation Loss: 242.6121, Validation Accuracy: 0.5540
# New best validation loss: 242.6121, saving model.
# Epoch 140/1000
# Training Loss: 267.0799, Training Accuracy: 0.5350
# Validation Loss: 242.6098, Validation Accuracy: 0.5539
# New best validation loss: 242.6098, saving model.
# Epoch 141/1000
# Training Loss: 266.7363, Training Accuracy: 0.5336
# Validation Loss: 242.6075, Validation Accuracy: 0.5539
# New best validation loss: 242.6075, saving model.
# Epoch 142/1000
# Training Loss: 268.2345, Training Accuracy: 0.5329
# Validation Loss: 242.6052, Validation Accuracy: 0.5538
# New best validation loss: 242.6052, saving model.
# Epoch 143/1000
# Training Loss: 268.3188, Training Accuracy: 0.5336
# Validation Loss: 242.6029, Validation Accuracy: 0.5537
# New best validation loss: 242.6029, saving model.
# Epoch 144/1000
# Training Loss: 267.3329, Training Accuracy: 0.5333
# Validation Loss: 242.6007, Validation Accuracy: 0.5537
# New best validation loss: 242.6007, saving model.
# Epoch 145/1000
# Training Loss: 267.4534, Training Accuracy: 0.5343
# Validation Loss: 242.5984, Validation Accuracy: 0.5536
# New best validation loss: 242.5984, saving model.
# Epoch 146/1000
# Training Loss: 269.4388, Training Accuracy: 0.5321
# Validation Loss: 242.5961, Validation Accuracy: 0.5536
# New best validation loss: 242.5961, saving model.
# Epoch 147/1000
# Training Loss: 269.0713, Training Accuracy: 0.5330
# Validation Loss: 242.5938, Validation Accuracy: 0.5535
# New best validation loss: 242.5938, saving model.
# Epoch 148/1000
# Training Loss: 267.3214, Training Accuracy: 0.5339
# Validation Loss: 242.5915, Validation Accuracy: 0.5535
# New best validation loss: 242.5915, saving model.
# Epoch 149/1000
# Training Loss: 269.3116, Training Accuracy: 0.5328
# Validation Loss: 242.5893, Validation Accuracy: 0.5534
# New best validation loss: 242.5893, saving model.
# Epoch 150/1000
# Training Loss: 269.2055, Training Accuracy: 0.5335
# Validation Loss: 242.5870, Validation Accuracy: 0.5533
# New best validation loss: 242.5870, saving model.
# Epoch 151/1000
# Training Loss: 266.5941, Training Accuracy: 0.5340
# Validation Loss: 242.5848, Validation Accuracy: 0.5533
# New best validation loss: 242.5848, saving model.
# Epoch 152/1000
# Training Loss: 268.7449, Training Accuracy: 0.5328
# Validation Loss: 242.5825, Validation Accuracy: 0.5532
# New best validation loss: 242.5825, saving model.
# Epoch 153/1000
# Training Loss: 266.7058, Training Accuracy: 0.5330
# Validation Loss: 242.5803, Validation Accuracy: 0.5531
# New best validation loss: 242.5803, saving model.
# Epoch 154/1000
# Training Loss: 267.8059, Training Accuracy: 0.5349
# Validation Loss: 242.5780, Validation Accuracy: 0.5531
# New best validation loss: 242.5780, saving model.
# Epoch 155/1000
# Training Loss: 268.6121, Training Accuracy: 0.5324
# Validation Loss: 242.5758, Validation Accuracy: 0.5530
# New best validation loss: 242.5758, saving model.
# Epoch 156/1000
# Training Loss: 269.1415, Training Accuracy: 0.5329
# Validation Loss: 242.5735, Validation Accuracy: 0.5529
# New best validation loss: 242.5735, saving model.
# Epoch 157/1000
# Training Loss: 268.2147, Training Accuracy: 0.5337
# Validation Loss: 242.5714, Validation Accuracy: 0.5529
# New best validation loss: 242.5714, saving model.
# Epoch 158/1000
# Training Loss: 268.3159, Training Accuracy: 0.5325
# Validation Loss: 242.5692, Validation Accuracy: 0.5528
# New best validation loss: 242.5692, saving model.
# Epoch 159/1000
# Training Loss: 266.7000, Training Accuracy: 0.5344
# Validation Loss: 242.5669, Validation Accuracy: 0.5527
# New best validation loss: 242.5669, saving model.
# Epoch 160/1000
# Training Loss: 267.3435, Training Accuracy: 0.5338
# Validation Loss: 242.5647, Validation Accuracy: 0.5526
# New best validation loss: 242.5647, saving model.
# Epoch 161/1000
# Training Loss: 267.0371, Training Accuracy: 0.5332
# Validation Loss: 242.5625, Validation Accuracy: 0.5526
# New best validation loss: 242.5625, saving model.
# Epoch 162/1000
# Training Loss: 267.7589, Training Accuracy: 0.5324
# Validation Loss: 242.5603, Validation Accuracy: 0.5525
# New best validation loss: 242.5603, saving model.
# Epoch 163/1000
# Training Loss: 267.3091, Training Accuracy: 0.5323
# Validation Loss: 242.5581, Validation Accuracy: 0.5525
# New best validation loss: 242.5581, saving model.
# Epoch 164/1000
# Training Loss: 267.9582, Training Accuracy: 0.5325
# Validation Loss: 242.5559, Validation Accuracy: 0.5524
# New best validation loss: 242.5559, saving model.
# Epoch 165/1000
# Training Loss: 268.2458, Training Accuracy: 0.5319
# Validation Loss: 242.5537, Validation Accuracy: 0.5523
# New best validation loss: 242.5537, saving model.
# Epoch 166/1000
# Training Loss: 268.9555, Training Accuracy: 0.5323
# Validation Loss: 242.5515, Validation Accuracy: 0.5523
# New best validation loss: 242.5515, saving model.
# Epoch 167/1000
# Training Loss: 266.8448, Training Accuracy: 0.5333
# Validation Loss: 242.5494, Validation Accuracy: 0.5522
# New best validation loss: 242.5494, saving model.
# Epoch 168/1000
# Training Loss: 267.2241, Training Accuracy: 0.5325
# Validation Loss: 242.5472, Validation Accuracy: 0.5521
# New best validation loss: 242.5472, saving model.
# Epoch 169/1000
# Training Loss: 266.8780, Training Accuracy: 0.5336
# Validation Loss: 242.5450, Validation Accuracy: 0.5520
# New best validation loss: 242.5450, saving model.
# Epoch 170/1000
# Training Loss: 268.2883, Training Accuracy: 0.5334
# Validation Loss: 242.5429, Validation Accuracy: 0.5520
# New best validation loss: 242.5429, saving model.
# Epoch 171/1000
# Training Loss: 267.7919, Training Accuracy: 0.5331
# Validation Loss: 242.5408, Validation Accuracy: 0.5519
# New best validation loss: 242.5408, saving model.
# Epoch 172/1000
# Training Loss: 267.5487, Training Accuracy: 0.5321
# Validation Loss: 242.5386, Validation Accuracy: 0.5519
# New best validation loss: 242.5386, saving model.
# Epoch 173/1000
# Training Loss: 266.3861, Training Accuracy: 0.5337
# Validation Loss: 242.5365, Validation Accuracy: 0.5518
# New best validation loss: 242.5365, saving model.
# Epoch 174/1000
# Training Loss: 268.5130, Training Accuracy: 0.5318
# Validation Loss: 242.5343, Validation Accuracy: 0.5517
# New best validation loss: 242.5343, saving model.
# Epoch 175/1000
# Training Loss: 267.2748, Training Accuracy: 0.5320
# Validation Loss: 242.5322, Validation Accuracy: 0.5516
# New best validation loss: 242.5322, saving model.
# Epoch 176/1000
# Training Loss: 266.4789, Training Accuracy: 0.5319
# Validation Loss: 242.5300, Validation Accuracy: 0.5515
# New best validation loss: 242.5300, saving model.
# Epoch 177/1000
# Training Loss: 266.7354, Training Accuracy: 0.5328
# Validation Loss: 242.5279, Validation Accuracy: 0.5515
# New best validation loss: 242.5279, saving model.
# Epoch 178/1000
# Training Loss: 267.4846, Training Accuracy: 0.5321
# Validation Loss: 242.5258, Validation Accuracy: 0.5514
# New best validation loss: 242.5258, saving model.
# Epoch 179/1000
# Training Loss: 267.6665, Training Accuracy: 0.5317
# Validation Loss: 242.5236, Validation Accuracy: 0.5513
# New best validation loss: 242.5236, saving model.
# Epoch 180/1000
# Training Loss: 268.2670, Training Accuracy: 0.5326
# Validation Loss: 242.5215, Validation Accuracy: 0.5512
# New best validation loss: 242.5215, saving model.
# Epoch 181/1000
# Training Loss: 269.5977, Training Accuracy: 0.5301
# Validation Loss: 242.5194, Validation Accuracy: 0.5512
# New best validation loss: 242.5194, saving model.
# Epoch 182/1000
# Training Loss: 267.0754, Training Accuracy: 0.5317
# Validation Loss: 242.5173, Validation Accuracy: 0.5511
# New best validation loss: 242.5173, saving model.
# Epoch 183/1000
# Training Loss: 266.6837, Training Accuracy: 0.5322
# Validation Loss: 242.5152, Validation Accuracy: 0.5510
# New best validation loss: 242.5152, saving model.
# Epoch 184/1000
# Training Loss: 269.0703, Training Accuracy: 0.5308
# Validation Loss: 242.5131, Validation Accuracy: 0.5510
# New best validation loss: 242.5131, saving model.
# Epoch 185/1000
# Training Loss: 267.7088, Training Accuracy: 0.5314
# Validation Loss: 242.5110, Validation Accuracy: 0.5509
# New best validation loss: 242.5110, saving model.
# Epoch 186/1000
# Training Loss: 267.2161, Training Accuracy: 0.5309
# Validation Loss: 242.5089, Validation Accuracy: 0.5508
# New best validation loss: 242.5089, saving model.
# Epoch 187/1000
# Training Loss: 266.8266, Training Accuracy: 0.5309
# Validation Loss: 242.5068, Validation Accuracy: 0.5508
# New best validation loss: 242.5068, saving model.
# Epoch 188/1000
# Training Loss: 266.3925, Training Accuracy: 0.5327
# Validation Loss: 242.5046, Validation Accuracy: 0.5507
# New best validation loss: 242.5046, saving model.
# Epoch 189/1000
# Training Loss: 268.9685, Training Accuracy: 0.5289
# Validation Loss: 242.5026, Validation Accuracy: 0.5506
# New best validation loss: 242.5026, saving model.
# Epoch 190/1000
# Training Loss: 267.0507, Training Accuracy: 0.5314
# Validation Loss: 242.5005, Validation Accuracy: 0.5505
# New best validation loss: 242.5005, saving model.
# Epoch 191/1000
# Training Loss: 268.8477, Training Accuracy: 0.5302
# Validation Loss: 242.4984, Validation Accuracy: 0.5504
# New best validation loss: 242.4984, saving model.
# Epoch 192/1000
# Training Loss: 267.2941, Training Accuracy: 0.5314
# Validation Loss: 242.4963, Validation Accuracy: 0.5503
# New best validation loss: 242.4963, saving model.
# Epoch 193/1000
# Training Loss: 267.8551, Training Accuracy: 0.5291
# Validation Loss: 242.4942, Validation Accuracy: 0.5502
# New best validation loss: 242.4942, saving model.
# Epoch 194/1000
# Training Loss: 266.5154, Training Accuracy: 0.5314
# Validation Loss: 242.4921, Validation Accuracy: 0.5501
# New best validation loss: 242.4921, saving model.
# Epoch 195/1000
# Training Loss: 266.4448, Training Accuracy: 0.5317
# Validation Loss: 242.4900, Validation Accuracy: 0.5501
# New best validation loss: 242.4900, saving model.
# Epoch 196/1000
# Training Loss: 268.3657, Training Accuracy: 0.5306
# Validation Loss: 242.4880, Validation Accuracy: 0.5500
# New best validation loss: 242.4880, saving model.
# Epoch 197/1000
# Training Loss: 267.0117, Training Accuracy: 0.5309
# Validation Loss: 242.4859, Validation Accuracy: 0.5499
# New best validation loss: 242.4859, saving model.
# Epoch 198/1000
# Training Loss: 267.7272, Training Accuracy: 0.5310
# Validation Loss: 242.4838, Validation Accuracy: 0.5499
# New best validation loss: 242.4838, saving model.
# Epoch 199/1000
# Training Loss: 267.4517, Training Accuracy: 0.5306
# Validation Loss: 242.4818, Validation Accuracy: 0.5498
# New best validation loss: 242.4818, saving model.
# Epoch 200/1000
# Training Loss: 268.2806, Training Accuracy: 0.5306
# Validation Loss: 242.4797, Validation Accuracy: 0.5498
# New best validation loss: 242.4797, saving model.
# Epoch 201/1000
# Training Loss: 266.9477, Training Accuracy: 0.5288
# Validation Loss: 242.4776, Validation Accuracy: 0.5497
# New best validation loss: 242.4776, saving model.
# Epoch 202/1000
# Training Loss: 267.1650, Training Accuracy: 0.5300
# Validation Loss: 242.4755, Validation Accuracy: 0.5497
# New best validation loss: 242.4755, saving model.
# Epoch 203/1000
# Training Loss: 267.5032, Training Accuracy: 0.5308
# Validation Loss: 242.4735, Validation Accuracy: 0.5496
# New best validation loss: 242.4735, saving model.
# Epoch 204/1000
# Training Loss: 267.6210, Training Accuracy: 0.5304
# Validation Loss: 242.4714, Validation Accuracy: 0.5495
# New best validation loss: 242.4714, saving model.
# Epoch 205/1000
# Training Loss: 266.3463, Training Accuracy: 0.5317
# Validation Loss: 242.4694, Validation Accuracy: 0.5495
# New best validation loss: 242.4694, saving model.
# Epoch 206/1000
# Training Loss: 266.8554, Training Accuracy: 0.5303
# Validation Loss: 242.4673, Validation Accuracy: 0.5495
# New best validation loss: 242.4673, saving model.
# Epoch 207/1000
# Training Loss: 266.7363, Training Accuracy: 0.5314
# Validation Loss: 242.4653, Validation Accuracy: 0.5494
# New best validation loss: 242.4653, saving model.
# Epoch 208/1000
# Training Loss: 268.0312, Training Accuracy: 0.5295
# Validation Loss: 242.4632, Validation Accuracy: 0.5493
# New best validation loss: 242.4632, saving model.
# Epoch 209/1000
# Training Loss: 267.9702, Training Accuracy: 0.5302
# Validation Loss: 242.4611, Validation Accuracy: 0.5493
# New best validation loss: 242.4611, saving model.
# Epoch 210/1000
# Training Loss: 267.7407, Training Accuracy: 0.5304
# Validation Loss: 242.4591, Validation Accuracy: 0.5492
# New best validation loss: 242.4591, saving model.
# Epoch 211/1000
# Training Loss: 268.1809, Training Accuracy: 0.5312
# Validation Loss: 242.4570, Validation Accuracy: 0.5492
# New best validation loss: 242.4570, saving model.
# Epoch 212/1000
# Training Loss: 267.7940, Training Accuracy: 0.5308
# Validation Loss: 242.4549, Validation Accuracy: 0.5492
# New best validation loss: 242.4549, saving model.
# Epoch 213/1000
# Training Loss: 266.5727, Training Accuracy: 0.5300
# Validation Loss: 242.4528, Validation Accuracy: 0.5491
# New best validation loss: 242.4528, saving model.
# Epoch 214/1000
# Training Loss: 266.6120, Training Accuracy: 0.5312
# Validation Loss: 242.4508, Validation Accuracy: 0.5491
# New best validation loss: 242.4508, saving model.
# Epoch 215/1000
# Training Loss: 269.0887, Training Accuracy: 0.5286
# Validation Loss: 242.4487, Validation Accuracy: 0.5490
# New best validation loss: 242.4487, saving model.
# Epoch 216/1000
# Training Loss: 266.7907, Training Accuracy: 0.5294
# Validation Loss: 242.4466, Validation Accuracy: 0.5490
# New best validation loss: 242.4466, saving model.
# Epoch 217/1000
# Training Loss: 267.3191, Training Accuracy: 0.5300
# Validation Loss: 242.4446, Validation Accuracy: 0.5490
# New best validation loss: 242.4446, saving model.
# Epoch 218/1000
# Training Loss: 266.2998, Training Accuracy: 0.5299
# Validation Loss: 242.4425, Validation Accuracy: 0.5490
# New best validation loss: 242.4425, saving model.
# Epoch 219/1000
# Training Loss: 267.3524, Training Accuracy: 0.5304
# Validation Loss: 242.4404, Validation Accuracy: 0.5489
# New best validation loss: 242.4404, saving model.
# Epoch 220/1000
# Training Loss: 267.5496, Training Accuracy: 0.5308
# Validation Loss: 242.4383, Validation Accuracy: 0.5489
# New best validation loss: 242.4383, saving model.
# Epoch 221/1000
# Training Loss: 268.5596, Training Accuracy: 0.5293
# Validation Loss: 242.4363, Validation Accuracy: 0.5489
# New best validation loss: 242.4363, saving model.
# Epoch 222/1000
# Training Loss: 266.7900, Training Accuracy: 0.5313
# Validation Loss: 242.4342, Validation Accuracy: 0.5488
# New best validation loss: 242.4342, saving model.
# Epoch 223/1000
# Training Loss: 267.0601, Training Accuracy: 0.5300
# Validation Loss: 242.4322, Validation Accuracy: 0.5488
# New best validation loss: 242.4322, saving model.
# Epoch 224/1000
# Training Loss: 267.0819, Training Accuracy: 0.5305
# Validation Loss: 242.4301, Validation Accuracy: 0.5487
# New best validation loss: 242.4301, saving model.
# Epoch 225/1000
# Training Loss: 269.1744, Training Accuracy: 0.5286
# Validation Loss: 242.4281, Validation Accuracy: 0.5487
# New best validation loss: 242.4281, saving model.
# Epoch 226/1000
# Training Loss: 268.3974, Training Accuracy: 0.5300
# Validation Loss: 242.4260, Validation Accuracy: 0.5486
# New best validation loss: 242.4260, saving model.
# Epoch 227/1000
# Training Loss: 266.8472, Training Accuracy: 0.5309
# Validation Loss: 242.4239, Validation Accuracy: 0.5485
# New best validation loss: 242.4239, saving model.
# Epoch 228/1000
# Training Loss: 268.1111, Training Accuracy: 0.5295
# Validation Loss: 242.4218, Validation Accuracy: 0.5485
# New best validation loss: 242.4218, saving model.
# Epoch 229/1000
# Training Loss: 266.6423, Training Accuracy: 0.5304
# Validation Loss: 242.4198, Validation Accuracy: 0.5484
# New best validation loss: 242.4198, saving model.
# Epoch 230/1000
# Training Loss: 267.7482, Training Accuracy: 0.5304
# Validation Loss: 242.4177, Validation Accuracy: 0.5484
# New best validation loss: 242.4177, saving model.
# Epoch 231/1000
# Training Loss: 266.9709, Training Accuracy: 0.5303
# Validation Loss: 242.4156, Validation Accuracy: 0.5484
# New best validation loss: 242.4156, saving model.
# Epoch 232/1000
# Training Loss: 267.1197, Training Accuracy: 0.5302
# Validation Loss: 242.4136, Validation Accuracy: 0.5483
# New best validation loss: 242.4136, saving model.
# Epoch 233/1000
# Training Loss: 267.7635, Training Accuracy: 0.5297
# Validation Loss: 242.4115, Validation Accuracy: 0.5483
# New best validation loss: 242.4115, saving model.
# Epoch 234/1000
# Training Loss: 267.2745, Training Accuracy: 0.5295
# Validation Loss: 242.4095, Validation Accuracy: 0.5482
# New best validation loss: 242.4095, saving model.
# Epoch 235/1000
# Training Loss: 268.2200, Training Accuracy: 0.5275
# Validation Loss: 242.4074, Validation Accuracy: 0.5482
# New best validation loss: 242.4074, saving model.
# Epoch 236/1000
# Training Loss: 267.2593, Training Accuracy: 0.5287
# Validation Loss: 242.4053, Validation Accuracy: 0.5481
# New best validation loss: 242.4053, saving model.
# Epoch 237/1000
# Training Loss: 266.9147, Training Accuracy: 0.5301
# Validation Loss: 242.4032, Validation Accuracy: 0.5481
# New best validation loss: 242.4032, saving model.
# Epoch 238/1000
# Training Loss: 267.0778, Training Accuracy: 0.5295
# Validation Loss: 242.4012, Validation Accuracy: 0.5480
# New best validation loss: 242.4012, saving model.
# Epoch 239/1000
# Training Loss: 267.6682, Training Accuracy: 0.5285
# Validation Loss: 242.3992, Validation Accuracy: 0.5479
# New best validation loss: 242.3992, saving model.
# Epoch 240/1000
# Training Loss: 268.1624, Training Accuracy: 0.5285
# Validation Loss: 242.3971, Validation Accuracy: 0.5479
# New best validation loss: 242.3971, saving model.
# Epoch 241/1000
# Training Loss: 266.2519, Training Accuracy: 0.5302
# Validation Loss: 242.3950, Validation Accuracy: 0.5479
# New best validation loss: 242.3950, saving model.
# Epoch 242/1000
# Training Loss: 267.4220, Training Accuracy: 0.5286
# Validation Loss: 242.3930, Validation Accuracy: 0.5478
# New best validation loss: 242.3930, saving model.
# Epoch 243/1000
# Training Loss: 266.7733, Training Accuracy: 0.5285
# Validation Loss: 242.3909, Validation Accuracy: 0.5478
# New best validation loss: 242.3909, saving model.
# Epoch 244/1000
# Training Loss: 267.6207, Training Accuracy: 0.5291
# Validation Loss: 242.3889, Validation Accuracy: 0.5477
# New best validation loss: 242.3889, saving model.
# Epoch 245/1000
# Training Loss: 266.9404, Training Accuracy: 0.5299
# Validation Loss: 242.3868, Validation Accuracy: 0.5477
# New best validation loss: 242.3868, saving model.
# Epoch 246/1000
# Training Loss: 267.4233, Training Accuracy: 0.5281
# Validation Loss: 242.3848, Validation Accuracy: 0.5476
# New best validation loss: 242.3848, saving model.
# Epoch 247/1000
# Training Loss: 268.8378, Training Accuracy: 0.5281
# Validation Loss: 242.3827, Validation Accuracy: 0.5475
# New best validation loss: 242.3827, saving model.
# Epoch 248/1000
# Training Loss: 267.5381, Training Accuracy: 0.5298
# Validation Loss: 242.3807, Validation Accuracy: 0.5475
# New best validation loss: 242.3807, saving model.
# Epoch 249/1000
# Training Loss: 268.2203, Training Accuracy: 0.5281
# Validation Loss: 242.3786, Validation Accuracy: 0.5474
# New best validation loss: 242.3786, saving model.
# Epoch 250/1000
# Training Loss: 267.4825, Training Accuracy: 0.5284
# Validation Loss: 242.3765, Validation Accuracy: 0.5473
# New best validation loss: 242.3765, saving model.
# Epoch 251/1000
# Training Loss: 266.1995, Training Accuracy: 0.5292
# Validation Loss: 242.3745, Validation Accuracy: 0.5472
# New best validation loss: 242.3745, saving model.
# Epoch 252/1000
# Training Loss: 267.3243, Training Accuracy: 0.5292
# Validation Loss: 242.3724, Validation Accuracy: 0.5472
# New best validation loss: 242.3724, saving model.
# Epoch 253/1000
# Training Loss: 267.8403, Training Accuracy: 0.5277
# Validation Loss: 242.3704, Validation Accuracy: 0.5471
# New best validation loss: 242.3704, saving model.
# Epoch 254/1000
# Training Loss: 266.3681, Training Accuracy: 0.5289
# Validation Loss: 242.3683, Validation Accuracy: 0.5470
# New best validation loss: 242.3683, saving model.
# Epoch 255/1000
# Training Loss: 266.9800, Training Accuracy: 0.5290
# Validation Loss: 242.3662, Validation Accuracy: 0.5470
# New best validation loss: 242.3662, saving model.
# Epoch 256/1000
# Training Loss: 268.6962, Training Accuracy: 0.5267
# Validation Loss: 242.3642, Validation Accuracy: 0.5468
# New best validation loss: 242.3642, saving model.
# Epoch 257/1000
# Training Loss: 266.0588, Training Accuracy: 0.5295
# Validation Loss: 242.3621, Validation Accuracy: 0.5468
# New best validation loss: 242.3621, saving model.
# Epoch 258/1000
# Training Loss: 266.7447, Training Accuracy: 0.5283
# Validation Loss: 242.3601, Validation Accuracy: 0.5467
# New best validation loss: 242.3601, saving model.
# Epoch 259/1000
# Training Loss: 266.3222, Training Accuracy: 0.5287
# Validation Loss: 242.3580, Validation Accuracy: 0.5466
# New best validation loss: 242.3580, saving model.
# Epoch 260/1000
# Training Loss: 266.6645, Training Accuracy: 0.5283
# Validation Loss: 242.3560, Validation Accuracy: 0.5465
# New best validation loss: 242.3560, saving model.
# Epoch 261/1000
# Training Loss: 266.8389, Training Accuracy: 0.5286
# Validation Loss: 242.3539, Validation Accuracy: 0.5464
# New best validation loss: 242.3539, saving model.
# Epoch 262/1000
# Training Loss: 267.9767, Training Accuracy: 0.5272
# Validation Loss: 242.3519, Validation Accuracy: 0.5463
# New best validation loss: 242.3519, saving model.
# Epoch 263/1000
# Training Loss: 268.7135, Training Accuracy: 0.5274
# Validation Loss: 242.3498, Validation Accuracy: 0.5462
# New best validation loss: 242.3498, saving model.
# Epoch 264/1000
# Training Loss: 269.8861, Training Accuracy: 0.5258
# Validation Loss: 242.3478, Validation Accuracy: 0.5461
# New best validation loss: 242.3478, saving model.
# Epoch 265/1000
# Training Loss: 266.4632, Training Accuracy: 0.5284
# Validation Loss: 242.3458, Validation Accuracy: 0.5460
# New best validation loss: 242.3458, saving model.
# Epoch 266/1000
# Training Loss: 267.1108, Training Accuracy: 0.5270
# Validation Loss: 242.3437, Validation Accuracy: 0.5459
# New best validation loss: 242.3437, saving model.
# Epoch 267/1000
# Training Loss: 267.7408, Training Accuracy: 0.5272
# Validation Loss: 242.3416, Validation Accuracy: 0.5458
# New best validation loss: 242.3416, saving model.
# Epoch 268/1000
# Training Loss: 270.1842, Training Accuracy: 0.5264
# Validation Loss: 242.3396, Validation Accuracy: 0.5458
# New best validation loss: 242.3396, saving model.
# Epoch 269/1000
# Training Loss: 267.7104, Training Accuracy: 0.5268
# Validation Loss: 242.3376, Validation Accuracy: 0.5457
# New best validation loss: 242.3376, saving model.
# Epoch 270/1000
# Training Loss: 267.6231, Training Accuracy: 0.5280
# Validation Loss: 242.3355, Validation Accuracy: 0.5456
# New best validation loss: 242.3355, saving model.
# Epoch 271/1000
# Training Loss: 266.5483, Training Accuracy: 0.5274
# Validation Loss: 242.3335, Validation Accuracy: 0.5455
# New best validation loss: 242.3335, saving model.
# Epoch 272/1000
# Training Loss: 266.9252, Training Accuracy: 0.5274
# Validation Loss: 242.3315, Validation Accuracy: 0.5455
# New best validation loss: 242.3315, saving model.
# Epoch 273/1000
# Training Loss: 268.2185, Training Accuracy: 0.5261
# Validation Loss: 242.3294, Validation Accuracy: 0.5454
# New best validation loss: 242.3294, saving model.
# Epoch 274/1000
# Training Loss: 266.8551, Training Accuracy: 0.5267
# Validation Loss: 242.3274, Validation Accuracy: 0.5453
# New best validation loss: 242.3274, saving model.
# Epoch 275/1000
# Training Loss: 266.6597, Training Accuracy: 0.5278
# Validation Loss: 242.3253, Validation Accuracy: 0.5452
# New best validation loss: 242.3253, saving model.
# Epoch 276/1000
# Training Loss: 267.2339, Training Accuracy: 0.5280
# Validation Loss: 242.3233, Validation Accuracy: 0.5451
# New best validation loss: 242.3233, saving model.
# Epoch 277/1000
# Training Loss: 266.4572, Training Accuracy: 0.5265
# Validation Loss: 242.3213, Validation Accuracy: 0.5451
# New best validation loss: 242.3213, saving model.
# Epoch 278/1000
# Training Loss: 266.2385, Training Accuracy: 0.5281
# Validation Loss: 242.3193, Validation Accuracy: 0.5450
# New best validation loss: 242.3193, saving model.
# Epoch 279/1000
# Training Loss: 268.0611, Training Accuracy: 0.5263
# Validation Loss: 242.3172, Validation Accuracy: 0.5450
# New best validation loss: 242.3172, saving model.
# Epoch 280/1000
# Training Loss: 267.1233, Training Accuracy: 0.5277
# Validation Loss: 242.3152, Validation Accuracy: 0.5449
# New best validation loss: 242.3152, saving model.
# Epoch 281/1000
# ...
# New best validation loss: 240.6359, saving model.
# Epoch 908/1000
# Training Loss: 265.8378, Training Accuracy: 0.3690
# Validation Loss: 240.6321, Validation Accuracy: 0.3816
# New best validation loss: 240.6321, saving model.
# Epoch 909/1000
# Training Loss: 265.2146, Training Accuracy: 0.3677
# Validation Loss: 240.6284, Validation Accuracy: 0.3811
# New best validation loss: 240.6284, saving model.
# Epoch 910/1000
# Training Loss: 265.8752, Training Accuracy: 0.3668
# Validation Loss: 240.6246, Validation Accuracy: 0.3805
# New best validation loss: 240.6246, saving model.
# Epoch 911/1000
# Training Loss: 267.0244, Training Accuracy: 0.3656
# Validation Loss: 240.6209, Validation Accuracy: 0.3798
# New best validation loss: 240.6209, saving model.
# Epoch 912/1000
# Training Loss: 265.2374, Training Accuracy: 0.3670
# Validation Loss: 240.6171, Validation Accuracy: 0.3792
# New best validation loss: 240.6171, saving model.
# Epoch 913/1000
# Training Loss: 264.9684, Training Accuracy: 0.3658
# Validation Loss: 240.6133, Validation Accuracy: 0.3786
# New best validation loss: 240.6133, saving model.
# Epoch 914/1000
# Training Loss: 265.3127, Training Accuracy: 0.3643
# Validation Loss: 240.6095, Validation Accuracy: 0.3782
# New best validation loss: 240.6095, saving model.
# Epoch 915/1000
# Training Loss: 267.3810, Training Accuracy: 0.3626
# Validation Loss: 240.6057, Validation Accuracy: 0.3776
# New best validation loss: 240.6057, saving model.
# Epoch 916/1000
# Training Loss: 265.4929, Training Accuracy: 0.3628
# Validation Loss: 240.6019, Validation Accuracy: 0.3771
# New best validation loss: 240.6019, saving model.
# Epoch 917/1000
# Training Loss: 266.6004, Training Accuracy: 0.3633
# Validation Loss: 240.5981, Validation Accuracy: 0.3764
# New best validation loss: 240.5981, saving model.
# Epoch 918/1000
# Training Loss: 265.0726, Training Accuracy: 0.3635
# Validation Loss: 240.5943, Validation Accuracy: 0.3759
# New best validation loss: 240.5943, saving model.
# Epoch 919/1000
# Training Loss: 264.8689, Training Accuracy: 0.3614
# Validation Loss: 240.5905, Validation Accuracy: 0.3753
# New best validation loss: 240.5905, saving model.
# Epoch 920/1000
# Training Loss: 264.5607, Training Accuracy: 0.3621
# Validation Loss: 240.5866, Validation Accuracy: 0.3747
# New best validation loss: 240.5866, saving model.
# Epoch 921/1000
# Training Loss: 265.9380, Training Accuracy: 0.3606
# Validation Loss: 240.5828, Validation Accuracy: 0.3741
# New best validation loss: 240.5828, saving model.
# Epoch 922/1000
# Training Loss: 266.1079, Training Accuracy: 0.3604
# Validation Loss: 240.5789, Validation Accuracy: 0.3736
# New best validation loss: 240.5789, saving model.
# Epoch 923/1000
# Training Loss: 265.0996, Training Accuracy: 0.3614
# Validation Loss: 240.5751, Validation Accuracy: 0.3730
# New best validation loss: 240.5751, saving model.
# Epoch 924/1000
# Training Loss: 266.2011, Training Accuracy: 0.3594
# Validation Loss: 240.5712, Validation Accuracy: 0.3724
# New best validation loss: 240.5712, saving model.
# Epoch 925/1000
# Training Loss: 265.0493, Training Accuracy: 0.3574
# Validation Loss: 240.5674, Validation Accuracy: 0.3719
# New best validation loss: 240.5674, saving model.
# Epoch 926/1000
# Training Loss: 265.3983, Training Accuracy: 0.3573
# Validation Loss: 240.5635, Validation Accuracy: 0.3713
# New best validation loss: 240.5635, saving model.
# Epoch 927/1000
# Training Loss: 264.8164, Training Accuracy: 0.3565
# Validation Loss: 240.5596, Validation Accuracy: 0.3707
# New best validation loss: 240.5596, saving model.
# Epoch 928/1000
# Training Loss: 266.3806, Training Accuracy: 0.3571
# Validation Loss: 240.5557, Validation Accuracy: 0.3702
# New best validation loss: 240.5557, saving model.
# Epoch 929/1000
# Training Loss: 266.2354, Training Accuracy: 0.3567
# Validation Loss: 240.5518, Validation Accuracy: 0.3697
# New best validation loss: 240.5518, saving model.
# Epoch 930/1000
# Training Loss: 265.3757, Training Accuracy: 0.3562
# Validation Loss: 240.5479, Validation Accuracy: 0.3691
# New best validation loss: 240.5479, saving model.
# Epoch 931/1000
# Training Loss: 264.5006, Training Accuracy: 0.3562
# Validation Loss: 240.5440, Validation Accuracy: 0.3686
# New best validation loss: 240.5440, saving model.
# Epoch 932/1000
# Training Loss: 266.6314, Training Accuracy: 0.3557
# Validation Loss: 240.5402, Validation Accuracy: 0.3682
# New best validation loss: 240.5402, saving model.
# Epoch 933/1000
# Training Loss: 265.3091, Training Accuracy: 0.3542
# Validation Loss: 240.5362, Validation Accuracy: 0.3676
# New best validation loss: 240.5362, saving model.
# Epoch 934/1000
# Training Loss: 265.2291, Training Accuracy: 0.3528
# Validation Loss: 240.5323, Validation Accuracy: 0.3671
# New best validation loss: 240.5323, saving model.
# Epoch 935/1000
# Training Loss: 266.8644, Training Accuracy: 0.3525
# Validation Loss: 240.5284, Validation Accuracy: 0.3665
# New best validation loss: 240.5284, saving model.
# Epoch 936/1000
# Training Loss: 264.4786, Training Accuracy: 0.3522
# Validation Loss: 240.5245, Validation Accuracy: 0.3659
# New best validation loss: 240.5245, saving model.
# Epoch 937/1000
# Training Loss: 266.3522, Training Accuracy: 0.3502
# Validation Loss: 240.5205, Validation Accuracy: 0.3654
# New best validation loss: 240.5205, saving model.
# Epoch 938/1000
# Training Loss: 267.6849, Training Accuracy: 0.3506
# Validation Loss: 240.5166, Validation Accuracy: 0.3647
# New best validation loss: 240.5166, saving model.
# Epoch 939/1000
# Training Loss: 264.3630, Training Accuracy: 0.3515
# Validation Loss: 240.5126, Validation Accuracy: 0.3642
# New best validation loss: 240.5126, saving model.
# Epoch 940/1000
# Training Loss: 266.8474, Training Accuracy: 0.3495
# Validation Loss: 240.5086, Validation Accuracy: 0.3637
# New best validation loss: 240.5086, saving model.
# Epoch 941/1000
# Training Loss: 266.9464, Training Accuracy: 0.3499
# Validation Loss: 240.5047, Validation Accuracy: 0.3631
# New best validation loss: 240.5047, saving model.
# Epoch 942/1000
# Training Loss: 266.5970, Training Accuracy: 0.3482
# Validation Loss: 240.5007, Validation Accuracy: 0.3626
# New best validation loss: 240.5007, saving model.
# Epoch 943/1000
# Training Loss: 264.6789, Training Accuracy: 0.3488
# Validation Loss: 240.4967, Validation Accuracy: 0.3621
# New best validation loss: 240.4967, saving model.
# Epoch 944/1000
# Training Loss: 264.9187, Training Accuracy: 0.3481
# Validation Loss: 240.4927, Validation Accuracy: 0.3615
# New best validation loss: 240.4927, saving model.
# Epoch 945/1000
# Training Loss: 265.4748, Training Accuracy: 0.3476
# Validation Loss: 240.4887, Validation Accuracy: 0.3611
# New best validation loss: 240.4887, saving model.
# Epoch 946/1000
# Training Loss: 265.8311, Training Accuracy: 0.3454
# Validation Loss: 240.4846, Validation Accuracy: 0.3605
# New best validation loss: 240.4846, saving model.
# Epoch 947/1000
# Training Loss: 266.4026, Training Accuracy: 0.3465
# Validation Loss: 240.4806, Validation Accuracy: 0.3599
# New best validation loss: 240.4806, saving model.
# Epoch 948/1000
# Training Loss: 266.0456, Training Accuracy: 0.3448
# Validation Loss: 240.4766, Validation Accuracy: 0.3594
# New best validation loss: 240.4766, saving model.
# Epoch 949/1000
# Training Loss: 265.4785, Training Accuracy: 0.3444
# Validation Loss: 240.4726, Validation Accuracy: 0.3588
# New best validation loss: 240.4726, saving model.
# Epoch 950/1000
# Training Loss: 264.8607, Training Accuracy: 0.3460
# Validation Loss: 240.4685, Validation Accuracy: 0.3584
# New best validation loss: 240.4685, saving model.
# Epoch 951/1000
# Training Loss: 266.8480, Training Accuracy: 0.3444
# Validation Loss: 240.4645, Validation Accuracy: 0.3578
# New best validation loss: 240.4645, saving model.
# Epoch 952/1000
# Training Loss: 265.5213, Training Accuracy: 0.3457
# Validation Loss: 240.4604, Validation Accuracy: 0.3573
# New best validation loss: 240.4604, saving model.
# Epoch 953/1000
# Training Loss: 264.7616, Training Accuracy: 0.3438
# Validation Loss: 240.4563, Validation Accuracy: 0.3567
# New best validation loss: 240.4563, saving model.
# Epoch 954/1000
# Training Loss: 264.8230, Training Accuracy: 0.3428
# Validation Loss: 240.4523, Validation Accuracy: 0.3563
# New best validation loss: 240.4523, saving model.
# Epoch 955/1000
# Training Loss: 264.9411, Training Accuracy: 0.3428
# Validation Loss: 240.4482, Validation Accuracy: 0.3558
# New best validation loss: 240.4482, saving model.
# Epoch 956/1000
# Training Loss: 265.6639, Training Accuracy: 0.3408
# Validation Loss: 240.4440, Validation Accuracy: 0.3552
# New best validation loss: 240.4440, saving model.
# Epoch 957/1000
# Training Loss: 264.3428, Training Accuracy: 0.3431
# Validation Loss: 240.4399, Validation Accuracy: 0.3546
# New best validation loss: 240.4399, saving model.
# Epoch 958/1000
# Training Loss: 264.8045, Training Accuracy: 0.3416
# Validation Loss: 240.4358, Validation Accuracy: 0.3541
# New best validation loss: 240.4358, saving model.
# Epoch 959/1000
# Training Loss: 265.3970, Training Accuracy: 0.3422
# Validation Loss: 240.4316, Validation Accuracy: 0.3536
# New best validation loss: 240.4316, saving model.
# Epoch 960/1000
# Training Loss: 266.3874, Training Accuracy: 0.3392
# Validation Loss: 240.4275, Validation Accuracy: 0.3530
# New best validation loss: 240.4275, saving model.
# Epoch 961/1000
# Training Loss: 265.0521, Training Accuracy: 0.3390
# Validation Loss: 240.4235, Validation Accuracy: 0.3525
# New best validation loss: 240.4235, saving model.
# Epoch 962/1000
# Training Loss: 266.2904, Training Accuracy: 0.3383
# Validation Loss: 240.4193, Validation Accuracy: 0.3519
# New best validation loss: 240.4193, saving model.
# Epoch 963/1000
# Training Loss: 265.0475, Training Accuracy: 0.3376
# Validation Loss: 240.4152, Validation Accuracy: 0.3515
# New best validation loss: 240.4152, saving model.
# Epoch 964/1000
# Training Loss: 265.9849, Training Accuracy: 0.3375
# Validation Loss: 240.4109, Validation Accuracy: 0.3509
# New best validation loss: 240.4109, saving model.
# Epoch 965/1000
# Training Loss: 265.9956, Training Accuracy: 0.3377
# Validation Loss: 240.4068, Validation Accuracy: 0.3504
# New best validation loss: 240.4068, saving model.
# Epoch 966/1000
# Training Loss: 265.2032, Training Accuracy: 0.3371
# Validation Loss: 240.4026, Validation Accuracy: 0.3499
# New best validation loss: 240.4026, saving model.
# Epoch 967/1000
# Training Loss: 264.5370, Training Accuracy: 0.3363
# Validation Loss: 240.3984, Validation Accuracy: 0.3494
# New best validation loss: 240.3984, saving model.
# Epoch 968/1000
# Training Loss: 266.2345, Training Accuracy: 0.3348
# Validation Loss: 240.3942, Validation Accuracy: 0.3488
# New best validation loss: 240.3942, saving model.
# Epoch 969/1000
# Training Loss: 268.4120, Training Accuracy: 0.3343
# Validation Loss: 240.3900, Validation Accuracy: 0.3483
# New best validation loss: 240.3900, saving model.
# Epoch 970/1000
# Training Loss: 264.5168, Training Accuracy: 0.3365
# Validation Loss: 240.3857, Validation Accuracy: 0.3477
# New best validation loss: 240.3857, saving model.
# Epoch 971/1000
# Training Loss: 264.5481, Training Accuracy: 0.3361
# Validation Loss: 240.3816, Validation Accuracy: 0.3473
# New best validation loss: 240.3816, saving model.
# Epoch 972/1000
# Training Loss: 265.4020, Training Accuracy: 0.3349
# Validation Loss: 240.3773, Validation Accuracy: 0.3467
# New best validation loss: 240.3773, saving model.
# Epoch 973/1000
# Training Loss: 265.3633, Training Accuracy: 0.3340
# Validation Loss: 240.3731, Validation Accuracy: 0.3461
# New best validation loss: 240.3731, saving model.
# Epoch 974/1000
# Training Loss: 264.7617, Training Accuracy: 0.3335
# Validation Loss: 240.3687, Validation Accuracy: 0.3457
# New best validation loss: 240.3687, saving model.
# Epoch 975/1000
# Training Loss: 266.6218, Training Accuracy: 0.3334
# Validation Loss: 240.3645, Validation Accuracy: 0.3451
# New best validation loss: 240.3645, saving model.
# Epoch 976/1000
# Training Loss: 265.4913, Training Accuracy: 0.3326
# Validation Loss: 240.3603, Validation Accuracy: 0.3446
# New best validation loss: 240.3603, saving model.
# Epoch 977/1000
# Training Loss: 266.2282, Training Accuracy: 0.3323
# Validation Loss: 240.3560, Validation Accuracy: 0.3441
# New best validation loss: 240.3560, saving model.
# Epoch 978/1000
# Training Loss: 265.7311, Training Accuracy: 0.3309
# Validation Loss: 240.3517, Validation Accuracy: 0.3436
# New best validation loss: 240.3517, saving model.
# Epoch 979/1000
# Training Loss: 265.8221, Training Accuracy: 0.3315
# Validation Loss: 240.3475, Validation Accuracy: 0.3431
# New best validation loss: 240.3475, saving model.
# Epoch 980/1000
# Training Loss: 265.9343, Training Accuracy: 0.3309
# Validation Loss: 240.3431, Validation Accuracy: 0.3426
# New best validation loss: 240.3431, saving model.
# Epoch 981/1000
# Training Loss: 265.1577, Training Accuracy: 0.3305
# Validation Loss: 240.3389, Validation Accuracy: 0.3421
# New best validation loss: 240.3389, saving model.
# Epoch 982/1000
# Training Loss: 265.2867, Training Accuracy: 0.3290
# Validation Loss: 240.3346, Validation Accuracy: 0.3417
# New best validation loss: 240.3346, saving model.
# Epoch 983/1000
# Training Loss: 266.1606, Training Accuracy: 0.3290
# Validation Loss: 240.3303, Validation Accuracy: 0.3412
# New best validation loss: 240.3303, saving model.
# Epoch 984/1000
# Training Loss: 266.1375, Training Accuracy: 0.3279
# Validation Loss: 240.3259, Validation Accuracy: 0.3406
# New best validation loss: 240.3259, saving model.
# Epoch 985/1000
# Training Loss: 265.3102, Training Accuracy: 0.3279
# Validation Loss: 240.3216, Validation Accuracy: 0.3401
# New best validation loss: 240.3216, saving model.
# Epoch 986/1000
# Training Loss: 267.7542, Training Accuracy: 0.3272
# Validation Loss: 240.3172, Validation Accuracy: 0.3395
# New best validation loss: 240.3172, saving model.
# Epoch 987/1000
# Training Loss: 265.4402, Training Accuracy: 0.3263
# Validation Loss: 240.3129, Validation Accuracy: 0.3389
# New best validation loss: 240.3129, saving model.
# Epoch 988/1000
# Training Loss: 265.4019, Training Accuracy: 0.3263
# Validation Loss: 240.3085, Validation Accuracy: 0.3385
# New best validation loss: 240.3085, saving model.
# Epoch 989/1000
# Training Loss: 266.5113, Training Accuracy: 0.3255
# Validation Loss: 240.3041, Validation Accuracy: 0.3380
# New best validation loss: 240.3041, saving model.
# Epoch 990/1000
# Training Loss: 266.6128, Training Accuracy: 0.3239
# Validation Loss: 240.2996, Validation Accuracy: 0.3375
# New best validation loss: 240.2996, saving model.
# Epoch 991/1000
# Training Loss: 265.5019, Training Accuracy: 0.3248
# Validation Loss: 240.2953, Validation Accuracy: 0.3370
# New best validation loss: 240.2953, saving model.
# Epoch 992/1000
# Training Loss: 265.4868, Training Accuracy: 0.3231
# Validation Loss: 240.2908, Validation Accuracy: 0.3365
# New best validation loss: 240.2908, saving model.
# Epoch 993/1000
# Training Loss: 266.0098, Training Accuracy: 0.3240
# Validation Loss: 240.2864, Validation Accuracy: 0.3360
# New best validation loss: 240.2864, saving model.
# Epoch 994/1000
# Training Loss: 264.2065, Training Accuracy: 0.3249
# Validation Loss: 240.2819, Validation Accuracy: 0.3356
# New best validation loss: 240.2819, saving model.
# Epoch 995/1000
# Training Loss: 265.1620, Training Accuracy: 0.3234
# Validation Loss: 240.2775, Validation Accuracy: 0.3351
# New best validation loss: 240.2775, saving model.
# Epoch 996/1000
# Training Loss: 266.6807, Training Accuracy: 0.3222
# Validation Loss: 240.2731, Validation Accuracy: 0.3347
# New best validation loss: 240.2731, saving model.
# Epoch 997/1000
# Training Loss: 264.9086, Training Accuracy: 0.3223
# Validation Loss: 240.2687, Validation Accuracy: 0.3342
# New best validation loss: 240.2687, saving model.
# Epoch 998/1000
# Training Loss: 264.7489, Training Accuracy: 0.3232
# Validation Loss: 240.2643, Validation Accuracy: 0.3337
# New best validation loss: 240.2643, saving model.
# Epoch 999/1000
# Training Loss: 265.3720, Training Accuracy: 0.3208
# Validation Loss: 240.2597, Validation Accuracy: 0.3333
# New best validation loss: 240.2597, saving model.
# Epoch 1000/1000
# Training Loss: 265.8337, Training Accuracy: 0.3206
# Validation Loss: 240.2552, Validation Accuracy: 0.3328
# New best validation loss: 240.2552, saving model.
